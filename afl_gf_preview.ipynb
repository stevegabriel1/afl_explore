# %%
import os 
os.getcwd()
# Out:
# '/Users/stevegabriel/data_projects/sports_data/afl_dataexploration'

# %%
import pandas as pd

# %%
updated = pd.read_csv("enh_2_aflresults_long.csv", sep =',')

# %% [markdown]
# ### This dataset includes all matches from the start of the 1897 season up to the third week of 2018 finals series

# %%
updated.tail()
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts     opp_team  op_pts  \
# 30807       15404  2018  SF  final  Collingwood      69   GWS Giants      59
# 30808       15405  2018  PF  final     Richmond      58  Collingwood      97
# 30809       15405  2018  PF  final  Collingwood      97     Richmond      58
# 30810       15406  2018  PF  final   West Coast     121    Melbourne      55
# 30811       15406  2018  PF  final    Melbourne      55   West Coast     121
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 30807         M.C.G.  CO  GW    10   1      10       W   VIC
# 30808         M.C.G.  RI  CO    39   0     -39       L   VIC
# 30809         M.C.G.  CO  RI    39   1      39       W   VIC
# 30810  Perth Stadium  WC  ME    66   1      66       W    WA
# 30811  Perth Stadium  ME  WC    66   0     -66       L    WA

# %% [markdown]
# ### Next week's Grand Final is:
# * Saturday 29 September: Collingwood v West Coast

# %% [markdown]
# ### Historical finals:

# %%
updated.iloc[:,:][(updated.tm == 'CO')&(updated.op == 'WC')&(updated.type == 'final')]
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts    opp_team  op_pts  \
# 20241       10121  1990  QF  final  Collingwood      90  West Coast      90
# 20244       10123  1990  QF  final  Collingwood     126  West Coast      67
# 21593       10797  1994  QF  final  Collingwood      80  West Coast      82
# 26405       13203  2007  SF  final  Collingwood      93  West Coast      74
# 27902       13952  2011  QF  final  Collingwood      82  West Coast      62
# 28325       14163  2012  SF  final  Collingwood      73  West Coast      60
# 30802       15402  2018  QF  final  Collingwood      70  West Coast      86
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 20241  Waverley Park  CO  WC     0   0       0       D   VIC
# 20244  Waverley Park  CO  WC    59   1      59       W   VIC
# 21593       W.A.C.A.  CO  WC     2   0      -2       L    WA
# 26405        Subiaco  CO  WC    19   1      19       W    WA
# ...

# %% [markdown]
# #### We see that in finals the results have been:
#     * Collingwood 4
#     * West Coast 2
#     * Draws 1

# %% [markdown]
# #### The first Collingwood v West Coast final was a QF in 1990 at VFL Park (Waverley) that resulted in a 90-90 draw.

# %% [markdown]
# ### Grand Finals with West Coast as one of the teams:

# %%
updated.iloc[:,:][(updated.tm == 'WC')&(updated.rnd == 'GF')]
# Out:
#        Unnamed: 0  year rnd   type        team  tm_pts  opp_team  op_pts  \
# 20596       10299  1991  GF  final  West Coast      86  Hawthorn     139
# 20940       10471  1992  GF  final  West Coast     113   Geelong      85
# 21602       10802  1994  GF  final  West Coast     143   Geelong      63
# 25673       12837  2005  GF  final  West Coast      54    Sydney      58
# 26043       13022  2006  GF  final  West Coast      85    Sydney      84
# 29570       14786  2015  GF  final  West Coast      61  Hawthorn     107
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 20596  Waverley Park  WC  HA    53   0     -53       L   VIC
# 20940         M.C.G.  WC  GE    28   1      28       W   VIC
# 21602         M.C.G.  WC  GE    80   1      80       W   VIC
# 25673         M.C.G.  WC  SY     4   0      -4       L   VIC
# 26043         M.C.G.  WC  SY     1   1       1       W   VIC
# 29570         M.C.G.  WC  HA    46   0     -46       L   VIC

# %% [markdown]
# #### West Coast GF results:

# %%
wc_gf = updated.iloc[:,:][(updated.tm == 'WC')&(updated.rnd == 'GF')]

# %%
wc_gf["outcome"].value_counts()
# Out:
# L    3
# W    3
# Name: outcome, dtype: int64

# %% [markdown]
# ### Grand Finals with Collingwood as one of the teams:

# %%
updated.iloc[:,:][(updated.tm == 'CO')&(updated.rnd == 'GF')]
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts         opp_team  \
# 683           342  1901  GF  final  Collingwood      16         Essendon
# 826           414  1902  GF  final  Collingwood      60         Essendon
# 969           485  1903  GF  final  Collingwood      31          Fitzroy
# 1255          628  1905  GF  final  Collingwood      17          Fitzroy
# 2101         1051  1910  GF  final  Collingwood      61          Carlton
# 2286         1144  1911  GF  final  Collingwood      35         Essendon
# 3003         1502  1915  GF  final  Collingwood      45          Carlton
# 3156         1579  1917  GF  final  Collingwood      74          Fitzroy
# 3275         1638  1918  GF  final  Collingwood      57  South Melbourne
# 3426         1714  1919  GF  final  Collingwood      78         Richmond
# 3579         1790  1920  GF  final  Collingwood      35         Richmond
# 3883         1942  1922  GF  final  Collingwood      68          Fitzroy
# ...

# %% [markdown]
# #### Collingwood GF results:

# %%
coll_gf = updated.iloc[:,:][(updated.tm == 'CO')&(updated.rnd == 'GF')]

# %%
coll_gf["outcome"].value_counts()
# Out:
# L    26
# W    15
# D     2
# Name: outcome, dtype: int64

# %% [markdown]
# ## West Coast all finals away

# %%
updated.iloc[:,:][(updated.tm == 'WC')&(updated.type == 'final') & (updated.state != 'WA')]
# Out:
#        Unnamed: 0  year rnd   type        team  tm_pts          opp_team  \
# 19600        9801  1988  EF  final  West Coast      71         Melbourne
# 20240       10121  1990  QF  final  West Coast      90       Collingwood
# 20245       10123  1990  QF  final  West Coast      67       Collingwood
# 20247       10124  1990  SF  final  West Coast     130         Melbourne
# 20250       10126  1990  PF  final  West Coast      58          Essendon
# 20593       10297  1991  SF  final  West Coast     117         Melbourne
# 20594       10298  1991  PF  final  West Coast      79           Geelong
# 20596       10299  1991  GF  final  West Coast      86          Hawthorn
# 20936       10469  1992  SF  final  West Coast     133           Geelong
# 20940       10471  1992  GF  final  West Coast     113           Geelong
# 21242       10622  1993  EF  final  West Coast     120   North Melbourne
# 21251       10626  1993  SF  final  West Coast      76          Essendon
# ...

# %%
wc_awayfins = updated.iloc[:,:][(updated.tm == 'WC')&(updated.type == 'final') & (updated.state != 'WA')]

# %%
wc_awayfins["outcome"].value_counts()
# Out:
# L    22
# W    11
# D     1
# Name: outcome, dtype: int64

# %%
# Plot the results (boxplots, absolute values of L versus W)

# %% [markdown]
# ## Fremantle has the same long travel distances

# %% [markdown]
# ### Fremantle all finals away

# %%
updated.iloc[:,:][(updated.tm == 'FR')&(updated.type == 'final') & (updated.state != 'WA')]
# Out:
#        Unnamed: 0  year rnd   type       team  tm_pts  opp_team  op_pts  \
# 26028       13015  2006  QF  final  Fremantle      46  Adelaide      76
# 26038       13020  2006  PF  final  Fremantle      92    Sydney     127
# 27514       13758  2010  SF  final  Fremantle      66   Geelong     135
# 28319       14160  2012  EF  final  Fremantle      96   Geelong      80
# 28322       14162  2012  SF  final  Fremantle      71  Adelaide      81
# 28731       14366  2013  QF  final  Fremantle      87   Geelong      72
# 28745       14373  2013  GF  final  Fremantle      62  Hawthorn      77
# 29145       14573  2014  QF  final  Fremantle      69    Sydney      93
#
#                    venue  tm  op  hvar  lr  tm_var outcome state
# 26028      Football Park  FR  AD    30   0     -30       L    SA
# 26038  Stadium Australia  FR  SY    35   0     -35       L   NSW
# 27514             M.C.G.  FR  GE    69   0     -69       L   VIC
# ...

# %%
fre_awayfins = updated.iloc[:,:][(updated.tm == 'FR')&(updated.type == 'final') & (updated.state != 'WA')]

# %%
fre_awayfins["outcome"].value_counts()
# Out:
# L    6
# W    2
# Name: outcome, dtype: int64
