# %% [markdown]
# ### Data file preparation steps:
#
#     * The raw text file from https://afltables.com/afl/stats/biglists/bg3.txt is saved as llist.txt
#     * The file llist.txt is then processed through the bash script file a_updater.sh to add commas at the appropriate locations and make other modifications, by typing ./a_updater into Terminal - ready to be imported from within Jupyter.

# %% [markdown]
# # Post week 1 of 2018 finals series

# %%
#%%html
#<img src="img/ess_stk.png" alt="Drawing" align="left" style="width: 800px;"/>

# %%
import os 
os.getcwd()
# Out:
# '/Users/stevegabriel/data_projects/sports_data'

# %%
import pandas as pd

# %%
cols = ['seq','date','round','team1','gls_1','bhs_1','pts_1','team2','gls_2','bhs_2','pts_2','venue']

# %% [markdown]
# #### The file will contain all matches starting from the first ever VFL game in 1987 - more than fifteen thousand games.

# %%
upd_round = pd.read_csv("newlist.csv", names = cols)
trans = upd_round

# %%
# Modify index to start at 1 
trans.index += 1
trans.tail()
# Out:
#          seq         date round       team1  gls_1  bhs_1  pts_1  \
# 15398  15398  26-Aug-2018   R23    St Kilda     14     10     94
# 15399  15399   6-Sep-2018    QF    Richmond     13     17     95
# 15400  15400   7-Sep-2018    EF   Melbourne     10     15     75
# 15401  15401   8-Sep-2018    EF   GW Sydney     10     19     79
# 15402  15402   8-Sep-2018    QF  West Coast     12     14     86
#
#                  team2  gls_2  bhs_2  pts_2          venue
# 15398  North Melbourne     17     15    117      Docklands
# 15399         Hawthorn      9     10     64         M.C.G.
# 15400          Geelong      6     10     46         M.C.G.
# 15401           Sydney      4      6     30         S.C.G.
# 15402      Collingwood     10     10     70  Perth Stadium

# %% [markdown]
# #### Shown above, the most four finals matches played on the weekend.

# %% [markdown]
# ### Adding additional information including state, and addition team names as two letter codes

# %%
# Add states
nsw = ['S.C.G.','Sydney Showground','Stadium Australia','Blacktown','Albury']
qld = ['Gabba','Carrara','Cazaly\'s Stadium','Brisbane Exhibition']
sa = ['Football Park','Adelaide Oval']
wa = ['W.A.C.A.','Perth Stadium','Subiaco']
nt = ['Marrara Oval','Traeger Park']
tas = ['York Park','Bellerive Oval','North Hobart']
act = ['Manuka Oval','Bruce Stadium']
intl = ['Wellington','Jiangwan Stadium']

# %%
def locations(x):
    if x in nsw:
        return "NSW"
    elif x in sa:
        return "SA"
    elif x in wa:
        return "WA"
    elif x in nt:
        return "NT"
    elif x in tas:
        return "TAS"
    elif x in intl:
        return "INTL"
    elif x in act:
        return "ACT"
    elif x in qld:
        return "QLD"
    else: 
        return "VIC"

# %%
trans["state"] = trans["venue"].apply(locations)
trans["state"].value_counts()
# Out:
# VIC     13034
# WA        641
# SA        573
# NSW       512
# QLD       474
# TAS        91
# ACT        48
# NT         24
# INTL        5
# Name: state, dtype: int64

# %%
## 1. HVAR & AGGR
trans['hvar'] = trans['pts_1'] - trans['pts_2']
trans['aggr'] = trans['pts_1'] + trans['pts_2']

# %%
## 2. YEAR & MONTH
import time
import datetime

# %%
trans['date'] = pd.to_datetime(trans['date'])
trans['year'], trans['month'] = trans['date'].dt.year, trans['date'].dt.month

# %%
## 3. ABBREVIATED CLUB NAMES
adelaide = ['Adelaide']
brisbane = ['Brisbane Bears','Brisbane Lions']
carlton = ['Carlton']
collingwood = ['Collingwood']
essendon = ['Essendon']
fitzroy = ['Fitzroy']
footscray = ['Footscray']
fremantle = ['Fremantle']
geelong = ['Geelong']
gold_coast = ['Gold Coast']
gws = ['GW Sydney']
hawthorn = ['Hawthorn']
melbourne = ['Melbourne']
north_melbourne = ['North Melbourne','Kangaroos']
port_adelaide = ['Port Adelaide']
richmond = ['Richmond']
south_melbourne = ['South Melbourne']
st_kilda = ['St Kilda']
sydney = ['Sydney']
west_coast = ['West Coast']
western_bulldogs = ['Western Bulldogs', 'Footscray']
university = ['University']

# %%
def team_shorten(x):
    if x in adelaide:
        return "AD"
    elif x in brisbane:
        return "BR"
    elif x in carlton:
        return "CA"
    elif x in collingwood:
        return "CO"
    elif x in essendon:
        return "ES"
    elif x in fitzroy:
        return "FI"
    elif x in fremantle:
        return "FR"
    elif x in geelong:
        return "GE"
    elif x in gold_coast:
        return "GC"
    elif x in gws:
        return "GW"
    elif x in hawthorn:
        return "HA"
    elif x in melbourne:
        return "ME"
    elif x in north_melbourne:
        return "NM"
    elif x in port_adelaide:
        return "PA"
    elif x in richmond:
        return "RI"
    elif x in south_melbourne:
        return "SM"
    elif x in st_kilda:
        return "SK"
    elif x in sydney:
        return "SY"
    elif x in west_coast:
        return "WC"
    elif x in western_bulldogs:
        return "WB"
    elif x in university:
        return "UN"
    else: 
        return "NOT_FOUND"

# %%
trans["t1"] = trans["team1"].apply(team_shorten)
trans["t2"] = trans["team2"].apply(team_shorten)

# %%
trans['t1'].value_counts().sum()
# Out:
# 15402

# %% [markdown]
# ##  FIX TEAM NAMES ANOMOLIES

# %% [markdown]
# * Merge Footscray & Western Bulldogs as **Western Bulldogs**
# * Merge North Melbourne with Kangaroos as **North Melbourne**
# * Merge Brisbane Lions with Brisbane Bears as **Brisbane**
# * Leave Sydney and **South Melbourne** as separate
# * Leave **Fitzroy** as separate
# * Modify GW Sydney to **GWS Giants**

# %%
# Function from Analytics Vidhya
def coding(col, codeDict):
  colCoded = pd.Series(col, copy=True)
  for key, value in codeDict.items():
    colCoded.replace(key, value, inplace=True)
  return colCoded

# %%
trans["team1"] = coding(trans["team1"], {'Footscray':'Western Bulldogs'})
trans["team2"] = coding(trans["team2"], {'Footscray':'Western Bulldogs'})
trans["team1"] = coding(trans["team1"], {'Kangaroos':'North Melbourne'})
trans["team2"] = coding(trans["team2"], {'Kangaroos':'North Melbourne'})
trans["team1"] = coding(trans["team1"], {'Brisbane Bears':'Brisbane','Brisbane Lions':'Brisbane'})
trans["team2"] = coding(trans["team2"], {'Brisbane Bears':'Brisbane','Brisbane Lions':'Brisbane'})
trans["team1"] = coding(trans["team1"], {'GW Sydney':'GWS Giants'})
trans["team2"] = coding(trans["team2"], {'GW Sydney':'GWS Giants'})

# %%
trans["team2"].value_counts()
# Out:
# Collingwood         1274
# Carlton             1251
# Essendon            1222
# Geelong             1219
# Melbourne           1190
# St Kilda            1190
# Richmond            1118
# North Melbourne      986
# Hawthorn             979
# Western Bulldogs     975
# Fitzroy              960
# South Melbourne      788
# Sydney               432
# West Coast           376
# Brisbane             359
# Adelaide             325
# Fremantle            273
# Port Adelaide        254
# Gold Coast            88
# GWS Giants            80
# University            63
# Name: team2, dtype: int64

# %% [markdown]
# #### The dataframe with the additional column. Currently it has one game per row.

# %%
trans.head(10)
# Out:
#     seq       date round            team1  gls_1  bhs_1  pts_1        team2  \
# 1     1 1897-05-08    R1          Fitzroy      6     13     49      Carlton
# 2     2 1897-05-08    R1      Collingwood      5     11     41     St Kilda
# 3     3 1897-05-08    R1          Geelong      3      6     24     Essendon
# 4     4 1897-05-08    R1  South Melbourne      3      9     27    Melbourne
# 5     5 1897-05-15    R2  South Melbourne      6      4     40      Carlton
# 6     6 1897-05-15    R2         Essendon      4      6     30  Collingwood
# 7     7 1897-05-15    R2         St Kilda      3      8     26      Fitzroy
# 8     8 1897-05-15    R2        Melbourne      9     10     64      Geelong
# 9     9 1897-05-22    R3      Collingwood      6      5     41      Geelong
# 10   10 1897-05-22    R3          Fitzroy      5      9     39    Melbourne
#
#     gls_2  bhs_2  pts_2           venue state  hvar  aggr  year  month  t1  t2
# 1       2      4     16    Brunswick St   VIC    33    65  1897      5  FI  CA
# 2       2      4     16   Victoria Park   VIC    25    57  1897      5  CO  SK
# 3       7      5     47      Corio Oval   VIC   -23    71  1897      5  GE  ES
# 4       6      8     44       Lake Oval   VIC   -17    71  1897      5  SM  ME
# 5       5      6     36       Lake Oval   VIC     4    76  1897      5  SM  CA
# 6       8      2     50  East Melbourne   VIC   -20    80  1897      5  ES  CO
# 7      10      6     66   Junction Oval   VIC   -40    92  1897      5  SK  FI
# 8       3      1     19          M.C.G.   VIC    45    83  1897      5  ME  GE
# 9       5      7     37   Victoria Park   VIC     4    78  1897      5  CO  GE
# 10      7      8     50    Brunswick St   VIC   -11    89  1897      5  FI  ME

# %% [markdown]
# ## ALL DRAWS (BOOLEAN)

# %%
def reg_draw(hvar):
    if hvar == 0:
        return 1
    else: return 0

# %%
trans["draw_rt"] = trans["hvar"].apply(reg_draw)

# %%
trans['draw_rt'].value_counts()
# Out:
# 0    15244
# 1      158
# Name: draw_rt, dtype: int64

# %% [markdown]
# ### The 158 draws above, represent the VFL/AFL games that have concluded in a draw result

# %% [markdown]
# ### The two ET (extra-time) draws below are statistically relevent, since they also ended regular full-time with both teams on the same score. However extra-time was applied to create a result, due to finals constraints.

# %%
def et_draw(seq):
    if seq == 10794:
        return 1
    elif seq == 13203:
        return 1
    else: return 0

# %%
trans["etime_draw"] = trans["seq"].apply(et_draw)
trans['etime_draw'].value_counts()
# Out:
# 0    15400
# 1        2
# Name: etime_draw, dtype: int64

# %%
### Add the two columns
trans['draws_all']  = trans['draw_rt'] + trans['etime_draw']
trans['draws_all'].value_counts()
# Out:
# 0    15242
# 1      160
# Name: draws_all, dtype: int64

# %%
# Check
trans.iloc[:,:][(trans.etime_draw == 1)]
# Out:
#          seq       date round            team1  gls_1  bhs_1  pts_1  \
# 10794  10794 1994-09-10    QF  North Melbourne     15     24    114
# 13203  13203 2007-09-14    SF      Collingwood     13     15     93
#
#             team2  gls_2  bhs_2    ...      state hvar aggr  year  month  t1  \
# 10794    Hawthorn     13     13    ...        VIC   23  205  1994      9  NM
# 13203  West Coast     10     14    ...         WA   19  167  2007      9  CO
#
#        t2 draw_rt etime_draw  draws_all
# 10794  HA       0          1          1
# 13203  WC       0          1          1
#
# [2 rows x 22 columns]

# %%
# 6. GAME CATEGORY
finals = ['EF','QF','SF','PF','GF']

# %%
def game_cat(x):
    if x in finals:
        return "final"
    else: 
        return "reg_season"

# %%
trans["type"] = trans["round"].apply(game_cat)

# %%
trans['type'].value_counts()
# Out:
# reg_season    14752
# final           650
# Name: type, dtype: int64

# %% [markdown]
# ### So, there have been 650 finals up to the end of week one of 2018 finals series.

# %%
def grouping_2K(seq):
    n=500
    if seq <= 4*n:
        return 1
    elif seq <= 8*n:
        return 2
    elif seq <= 12*n:
        return 3
    elif seq <= 16*n:
        return 4
    elif seq <= 20*n:
        return 5
    elif seq <= 24*n:
        return 6
    elif seq <= 28*n:
        return 7
    else: return 8

# %%
trans["grp_2K"] = trans["seq"].apply(grouping_2K)

# %%
def grouping_1K(seq):
    n=1000
    if seq <= n:
        return 1
    elif seq <= 2*n:
        return 2
    elif seq <= 3*n:
        return 3
    elif seq <= 4*n:
        return 4
    elif seq <= 5*n:
        return 5
    elif seq <= 6*n:
        return 6
    elif seq <= 7*n:
        return 7
    elif seq <= 8*n:
        return 8
    elif seq <= 9*n:
        return 9
    elif seq <= 10*n:
        return 10
    elif seq <= 11*n:
        return 11
    elif seq <= 12*n:
        return 12
    elif seq <= 13*n:
        return 13
    elif seq <= 14*n:
        return 14
    elif seq <= 15*n:
        return 15
    else: return 16

# %%
trans["grp_1K"] = trans["seq"].apply(grouping_1K)

# %%
# Export the data frame for use in afl draws EDA
trans.to_csv('all_afl_wide.csv')

# %% [markdown]
# ## ADD res1 and res2 columns as categorical 1 = win, 2 = loss, 3 = draw based on hvar (ignoring the two extra time finals)

# %%
def result_cat_h(hvar):
    if hvar > 0:
        return 1
    elif hvar < 0:
        return 2
    else: return 3

# %%
def result_cat_a(hvar):
    if hvar > 0:
        return 2
    elif hvar < 0:
        return 1
    else: return 3

# %%
trans['res1'] = trans['hvar'].apply(result_cat_h)
trans['res2'] = trans['hvar'].apply(result_cat_a)

# %%
trans.tail(9)
# Out:
#          seq       date round       team1  gls_1  bhs_1  pts_1  \
# 15394  15394 2018-08-25   R23     Carlton      8     13     61
# 15395  15395 2018-08-25   R23      Sydney     10     14     74
# 15396  15396 2018-08-26   R23    Brisbane     11      6     72
# 15397  15397 2018-08-26   R23   Melbourne     15     12    102
# 15398  15398 2018-08-26   R23    St Kilda     14     10     94
# 15399  15399 2018-09-06    QF    Richmond     13     17     95
# 15400  15400 2018-09-07    EF   Melbourne     10     15     75
# 15401  15401 2018-09-08    EF  GWS Giants     10     19     79
# 15402  15402 2018-09-08    QF  West Coast     12     14     86
#
#                  team2  gls_2  bhs_2  ...   t1  t2 draw_rt  etime_draw  \
# 15394         Adelaide     26      9  ...   CA  AD       0           0
# 15395         Hawthorn     12     11  ...   SY  HA       0           0
# 15396       West Coast     14     14  ...   BR  WC       0           0
# 15397       GWS Giants      8      9  ...   ME  GW       0           0
# 15398  North Melbourne     17     15  ...   SK  NM       0           0
# 15399         Hawthorn      9     10  ...   RI  HA       0           0
# 15400          Geelong      6     10  ...   ME  GE       0           0
# 15401           Sydney      4      6  ...   GW  SY       0           0
# 15402      Collingwood     10     10  ...   WC  CO       0           0
#
#        draws_all        type  grp_2K grp_1K res1  res2
# 15394          0  reg_season       8     16    2     1
# 15395          0  reg_season       8     16    2     1
# 15396          0  reg_season       8     16    2     1
# 15397          0  reg_season       8     16    1     2
# 15398          0  reg_season       8     16    2     1
# 15399          0       final       8     16    1     2
# 15400          0       final       8     16    1     2
# 15401          0       final       8     16    1     2
# 15402          0       final       8     16    1     2
#
# [9 rows x 27 columns]

# %%
trans.shape
# Out:
# (15402, 27)

# %% [markdown]
# ### Export enhanced results 1897-2018 with 27 columns

# %%
trans.to_csv('enh_1_aflresults.csv')

# %% [markdown]
# ## STAGE TWO
# ## 9. Reduce and re-order the data frame to prepare for for Long format

# %%
tracker = trans
tracker = tracker[['year', 'team1','pts_1','team2','pts_2','venue','t1','t2','hvar']]
tracker.tail()
# Out:
#        year       team1  pts_1            team2  pts_2          venue  t1  t2  \
# 15398  2018    St Kilda     94  North Melbourne    117      Docklands  SK  NM
# 15399  2018    Richmond     95         Hawthorn     64         M.C.G.  RI  HA
# 15400  2018   Melbourne     75          Geelong     46         M.C.G.  ME  GE
# 15401  2018  GWS Giants     79           Sydney     30         S.C.G.  GW  SY
# 15402  2018  West Coast     86      Collingwood     70  Perth Stadium  WC  CO
#
#        hvar
# 15398   -23
# 15399    31
# 15400    29
# 15401    49
# 15402    16

# %% [markdown]
# ### Create two new columns with values 1 and 0 for the two subsets

# %%
tracker['subset_1'] = 1
tracker['subset_2'] = 0
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tracker.tail(9)
# Out:
#        year       team1  pts_1            team2  pts_2          venue  t1  t2  \
# 15394  2018     Carlton     61         Adelaide    165      Docklands  CA  AD
# 15395  2018      Sydney     74         Hawthorn     83         S.C.G.  SY  HA
# 15396  2018    Brisbane     72       West Coast     98          Gabba  BR  WC
# 15397  2018   Melbourne    102       GWS Giants     57         M.C.G.  ME  GW
# 15398  2018    St Kilda     94  North Melbourne    117      Docklands  SK  NM
# 15399  2018    Richmond     95         Hawthorn     64         M.C.G.  RI  HA
# 15400  2018   Melbourne     75          Geelong     46         M.C.G.  ME  GE
# 15401  2018  GWS Giants     79           Sydney     30         S.C.G.  GW  SY
# 15402  2018  West Coast     86      Collingwood     70  Perth Stadium  WC  CO
#
#        hvar  subset_1  subset_2
# 15394  -104         1         0
# 15395    -9         1         0
# 15396   -26         1         0
# 15397    45         1         0
# 15398   -23         1         0
# 15399    31         1         0
# 15400    29         1         0
# 15401    49         1         0
# 15402    16         1         0

# %%
droplist_1 = ['subset_2']
droplist_2 = ['subset_1']

# %%
left_team = tracker.drop(droplist_1, axis = 1)
right_team = tracker.drop(droplist_2, axis = 1)

# %%
left_team.shape
# Out:
# (15402, 10)

# %%
right_team.shape
# Out:
# (15402, 10)

# %% [markdown]
# # Rename columns in each dframe

# %%
left_team.columns = ['year','team','tm_pts','opp_team','op_pts','venue','tm','op','hvar','lr']
right_team.columns = ['year','opp_team','op_pts','team','tm_pts','venue','op','tm','hvar','lr']

# %% [markdown]
# ### Now re-order the second dframe to match columns

# %% [markdown]
# ### Note double brackets to re-order

# %%
right_team = right_team[['year', 'team','tm_pts','opp_team','op_pts','venue','tm','op','hvar','lr']]
right_team.tail()
# Out:
#        year             team  tm_pts    opp_team  op_pts          venue  tm  \
# 15398  2018  North Melbourne     117    St Kilda      94      Docklands  NM
# 15399  2018         Hawthorn      64    Richmond      95         M.C.G.  HA
# 15400  2018          Geelong      46   Melbourne      75         M.C.G.  GE
# 15401  2018           Sydney      30  GWS Giants      79         S.C.G.  SY
# 15402  2018      Collingwood      70  West Coast      86  Perth Stadium  CO
#
#        op  hvar  lr
# 15398  SK   -23   0
# 15399  RI    31   0
# 15400  ME    29   0
# 15401  GW    49   0
# 15402  WC    16   0

# %%
right_team.tail()
# Out:
#        year             team  tm_pts    opp_team  op_pts          venue  tm  \
# 15398  2018  North Melbourne     117    St Kilda      94      Docklands  NM
# 15399  2018         Hawthorn      64    Richmond      95         M.C.G.  HA
# 15400  2018          Geelong      46   Melbourne      75         M.C.G.  GE
# 15401  2018           Sydney      30  GWS Giants      79         S.C.G.  SY
# 15402  2018      Collingwood      70  West Coast      86  Perth Stadium  CO
#
#        op  hvar  lr
# 15398  SK   -23   0
# 15399  RI    31   0
# 15400  ME    29   0
# 15401  GW    49   0
# 15402  WC    16   0

# %%
left_team.tail()
# Out:
#        year        team  tm_pts         opp_team  op_pts          venue  tm  \
# 15398  2018    St Kilda      94  North Melbourne     117      Docklands  SK
# 15399  2018    Richmond      95         Hawthorn      64         M.C.G.  RI
# 15400  2018   Melbourne      75          Geelong      46         M.C.G.  ME
# 15401  2018  GWS Giants      79           Sydney      30         S.C.G.  GW
# 15402  2018  West Coast      86      Collingwood      70  Perth Stadium  WC
#
#        op  hvar  lr
# 15398  NM   -23   1
# 15399  HA    31   1
# 15400  GE    29   1
# 15401  SY    49   1
# 15402  CO    16   1

# %% [markdown]
# ## CONCATENATION

# %% [markdown]
# ### Can now concatenate the two dframes, as in si_week11

# %%
merge_ft = pd.concat([left_team, right_team], axis=0)
merge_ft.head()
# Out:
#    year             team  tm_pts   opp_team  op_pts          venue  tm  op  \
# 1  1897          Fitzroy      49    Carlton      16   Brunswick St  FI  CA
# 2  1897      Collingwood      41   St Kilda      16  Victoria Park  CO  SK
# 3  1897          Geelong      24   Essendon      47     Corio Oval  GE  ES
# 4  1897  South Melbourne      27  Melbourne      44      Lake Oval  SM  ME
# 5  1897  South Melbourne      40    Carlton      36      Lake Oval  SM  CA
#
#    hvar  lr
# 1    33   1
# 2    25   1
# 3   -23   1
# 4   -17   1
# 5     4   1

# %% [markdown]
# #### The new long data frame consisting of 30,000 plus rows:

# %%
merge_ft.shape
# Out:
# (30804, 10)

# %% [markdown]
# # The following is to keep each game together (two rows per game)

# %%
merge_ft.sort_index(inplace=True)
merge_ft.head(10)
# Out:
#    year             team  tm_pts         opp_team  op_pts          venue  tm  \
# 1  1897          Fitzroy      49          Carlton      16   Brunswick St  FI
# 1  1897          Carlton      16          Fitzroy      49   Brunswick St  CA
# 2  1897      Collingwood      41         St Kilda      16  Victoria Park  CO
# 2  1897         St Kilda      16      Collingwood      41  Victoria Park  SK
# 3  1897          Geelong      24         Essendon      47     Corio Oval  GE
# 3  1897         Essendon      47          Geelong      24     Corio Oval  ES
# 4  1897  South Melbourne      27        Melbourne      44      Lake Oval  SM
# 4  1897        Melbourne      44  South Melbourne      27      Lake Oval  ME
# 5  1897  South Melbourne      40          Carlton      36      Lake Oval  SM
# 5  1897          Carlton      36  South Melbourne      40      Lake Oval  CA
#
#    op  hvar  lr
# 1  CA    33   1
# 1  FI    33   0
# 2  SK    25   1
# 2  CO    25   0
# 3  ES   -23   1
# 3  GE   -23   0
# 4  ME   -17   1
# 4  SM   -17   0
# 5  CA     4   1
# 5  SM     4   0

# %%
merge_ft.tail()
# Out:
#        year         team  tm_pts     opp_team  op_pts          venue  tm  op  \
# 15400  2018    Melbourne      75      Geelong      46         M.C.G.  ME  GE
# 15401  2018       Sydney      30   GWS Giants      79         S.C.G.  SY  GW
# 15401  2018   GWS Giants      79       Sydney      30         S.C.G.  GW  SY
# 15402  2018   West Coast      86  Collingwood      70  Perth Stadium  WC  CO
# 15402  2018  Collingwood      70   West Coast      86  Perth Stadium  CO  WC
#
#        hvar  lr
# 15400    29   1
# 15401    49   0
# 15401    49   1
# 15402    16   1
# 15402    16   0

# %% [markdown]
# ## There are actually 30,804 rows, indexing isn't  sequential

# %% [markdown]
# ## Create team result column

# %%
def neg_hvar(hvar):
        return -1*hvar

# %%
merge_ft["neg_dummy"] = merge_ft['hvar'].apply(neg_hvar)

# %%
merge_ft.tail()
# Out:
#        year         team  tm_pts     opp_team  op_pts          venue  tm  op  \
# 15400  2018    Melbourne      75      Geelong      46         M.C.G.  ME  GE
# 15401  2018       Sydney      30   GWS Giants      79         S.C.G.  SY  GW
# 15401  2018   GWS Giants      79       Sydney      30         S.C.G.  GW  SY
# 15402  2018   West Coast      86  Collingwood      70  Perth Stadium  WC  CO
# 15402  2018  Collingwood      70   West Coast      86  Perth Stadium  CO  WC
#
#        hvar  lr  neg_dummy
# 15400    29   1        -29
# 15401    49   0        -49
# 15401    49   1        -49
# 15402    16   1        -16
# 15402    16   0        -16

# %%
def team_var(hvar):
    if merge_ft['lr'] == 1:
        return hvar
    else: return neg_dummy

# %%
def new_lr(lr):
    if lr == 0:
        return -1
    else: return 1

# %%
merge_ft["new_lr"] = merge_ft['lr'].apply(new_lr)
merge_ft["tm_var"] = merge_ft['new_lr']*merge_ft['hvar']

# %%
merge_ft.tail()
# Out:
#        year         team  tm_pts     opp_team  op_pts          venue  tm  op  \
# 15400  2018    Melbourne      75      Geelong      46         M.C.G.  ME  GE
# 15401  2018       Sydney      30   GWS Giants      79         S.C.G.  SY  GW
# 15401  2018   GWS Giants      79       Sydney      30         S.C.G.  GW  SY
# 15402  2018   West Coast      86  Collingwood      70  Perth Stadium  WC  CO
# 15402  2018  Collingwood      70   West Coast      86  Perth Stadium  CO  WC
#
#        hvar  lr  neg_dummy  new_lr  tm_var
# 15400    29   1        -29       1      29
# 15401    49   0        -49      -1     -49
# 15401    49   1        -49       1      49
# 15402    16   1        -16       1      16
# 15402    16   0        -16      -1     -16

# %% [markdown]
# ### Can now remove the columns new_lr and neg_dummy, which were used to create tm_var

# %%
merge_ft = merge_ft.drop(['neg_dummy', 'new_lr'], axis=1)

# %%
merge_ft.head()
# Out:
#    year         team  tm_pts     opp_team  op_pts          venue  tm  op  \
# 1  1897      Fitzroy      49      Carlton      16   Brunswick St  FI  CA
# 1  1897      Carlton      16      Fitzroy      49   Brunswick St  CA  FI
# 2  1897  Collingwood      41     St Kilda      16  Victoria Park  CO  SK
# 2  1897     St Kilda      16  Collingwood      41  Victoria Park  SK  CO
# 3  1897      Geelong      24     Essendon      47     Corio Oval  GE  ES
#
#    hvar  lr  tm_var
# 1    33   1      33
# 1    33   0     -33
# 2    25   1      25
# 2    25   0     -25
# 3   -23   1     -23

# %% [markdown]
# ### Note that the column 'lr' denotes left right, so there are only two different values (1 denotes left)

# %%
merge_ft['lr'].value_counts()
# Out:
# 1    15402
# 0    15402
# Name: lr, dtype: int64

# %% [markdown]
# ## New function for win/loss/draw (W/L/D)

# %%
def outcome(tm_var):
    if tm_var >= 1:
        return "W"
    elif tm_var <= -1:
        return "L"
    elif tm_var == 0:
        return "D"
    else: return "Unknown"

# %%
merge_ft["outcome"] = merge_ft['tm_var'].apply(outcome)

# %%
merge_ft.head()
# Out:
#    year         team  tm_pts     opp_team  op_pts          venue  tm  op  \
# 1  1897      Fitzroy      49      Carlton      16   Brunswick St  FI  CA
# 1  1897      Carlton      16      Fitzroy      49   Brunswick St  CA  FI
# 2  1897  Collingwood      41     St Kilda      16  Victoria Park  CO  SK
# 2  1897     St Kilda      16  Collingwood      41  Victoria Park  SK  CO
# 3  1897      Geelong      24     Essendon      47     Corio Oval  GE  ES
#
#    hvar  lr  tm_var outcome
# 1    33   1      33       W
# 1    33   0     -33       L
# 2    25   1      25       W
# 2    25   0     -25       L
# 3   -23   1     -23       L

# %%
merge_ft.tail(9)
# Out:
#        year         team  tm_pts         opp_team  op_pts          venue  tm  \
# 15398  2018     St Kilda      94  North Melbourne     117      Docklands  SK
# 15399  2018     Hawthorn      64         Richmond      95         M.C.G.  HA
# 15399  2018     Richmond      95         Hawthorn      64         M.C.G.  RI
# 15400  2018      Geelong      46        Melbourne      75         M.C.G.  GE
# 15400  2018    Melbourne      75          Geelong      46         M.C.G.  ME
# 15401  2018       Sydney      30       GWS Giants      79         S.C.G.  SY
# 15401  2018   GWS Giants      79           Sydney      30         S.C.G.  GW
# 15402  2018   West Coast      86      Collingwood      70  Perth Stadium  WC
# 15402  2018  Collingwood      70       West Coast      86  Perth Stadium  CO
#
#        op  hvar  lr  tm_var outcome
# 15398  NM   -23   1     -23       L
# 15399  RI    31   0     -31       L
# 15399  HA    31   1      31       W
# 15400  ME    29   0     -29       L
# 15400  GE    29   1      29       W
# 15401  GW    49   0     -49       L
# 15401  SY    49   1      49       W
# 15402  CO    16   1      16       W
# 15402  WC    16   0     -16       L

# %% [markdown]
# ### Add the state column back in, using locations function.

# %%
merge_ft["state"] = merge_ft["venue"].apply(locations)
merge_ft["state"].value_counts()
# Out:
# VIC     26068
# WA       1282
# SA       1146
# NSW      1024
# QLD       948
# TAS       182
# ACT        96
# NT         48
# INTL       10
# Name: state, dtype: int64

# %% [markdown]
# ### Export enhanced results v2 with long format two rows per match

# %%
merge_ft.to_csv('enh_2_aflresults_long.csv')

# %% [markdown]
# ## Research for Week 2 of finals 2018 using Pandas filtering:
# ### * Hawthorn v Melbourne
# ### * Collingwood v GWS Giants

# %% [markdown]
# ### Recent contests Hawthorn v Melbourne

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'ME') & (merge_ft.op == 'HA')].tail(6)
# Out:
#        year       team  tm_pts  opp_team  op_pts   venue  tm  op  hvar  lr  \
# 14539  2014  Melbourne      65  Hawthorn     115  M.C.G.  ME  HA    50   0
# 14637  2015  Melbourne      50  Hawthorn     155  M.C.G.  ME  HA   105   0
# 14878  2016  Melbourne      64  Hawthorn      82  M.C.G.  ME  HA    18   0
# 14951  2016  Melbourne     110  Hawthorn      81  M.C.G.  ME  HA    29   1
# 15055  2017  Melbourne      91  Hawthorn      94  M.C.G.  ME  HA    -3   1
# 15235  2018  Melbourne      48  Hawthorn     115  M.C.G.  ME  HA    67   0
#
#        tm_var outcome state
# 14539     -50       L   VIC
# 14637    -105       L   VIC
# 14878     -18       L   VIC
# 14951      29       W   VIC
# 15055      -3       L   VIC
# 15235     -67       L   VIC

# %% [markdown]
# ### Hawks recent form

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'HA')].tail(10)
# Out:
#        year      team  tm_pts          opp_team  op_pts              venue  \
# 15323  2018  Hawthorn      84        GWS Giants      95  Sydney Showground
# 15331  2018  Hawthorn     122  Western Bulldogs      59          Docklands
# 15338  2018  Hawthorn      65          Brisbane      98          York Park
# 15351  2018  Hawthorn     124           Carlton      52          Docklands
# 15362  2018  Hawthorn     112         Fremantle      53      Perth Stadium
# 15364  2018  Hawthorn     107          Essendon     103             M.C.G.
# 15373  2018  Hawthorn      71           Geelong      60             M.C.G.
# 15385  2018  Hawthorn      80          St Kilda      76          Docklands
# 15395  2018  Hawthorn      83            Sydney      74             S.C.G.
# 15399  2018  Hawthorn      64          Richmond      95             M.C.G.
#
#        tm  op  hvar  lr  tm_var outcome state
# 15323  HA  GW    11   0     -11       L   NSW
# 15331  HA  WB   -63   0      63       W   VIC
# 15338  HA  BR   -33   1     -33       L   TAS
# 15351  HA  CA   -72   0      72       W   VIC
# 15362  HA  FR   -59   0      59       W    WA
# 15364  HA  ES     4   1       4       W   VIC
# 15373  HA  GE    11   1      11       W   VIC
# 15385  HA  SK    -4   0       4       W   VIC
# 15395  HA  SY    -9   0       9       W   NSW
# 15399  HA  RI    31   0     -31       L   VIC

# %% [markdown]
# ### Recent contests Collingwood v GWS in Melbourne

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.op == 'GW')].tail(12)
# Out:
#        year         team  tm_pts    opp_team  op_pts              venue  tm  \
# 14107  2012  Collingwood     174  GWS Giants      54  Sydney Showground  CO
# 14314  2013  Collingwood     106  GWS Giants      66             M.C.G.  CO
# 14557  2014  Collingwood      75  GWS Giants      67  Sydney Showground  CO
# 14675  2015  Collingwood     119  GWS Giants      77             M.C.G.  CO
# 14915  2016  Collingwood     125  GWS Giants      93  Sydney Showground  CO
# 15060  2017  Collingwood      99  GWS Giants     102  Sydney Showground  CO
# 15213  2018  Collingwood      79  GWS Giants      95             M.C.G.  CO
#
#        op  hvar  lr  tm_var outcome state
# 14107  GW  -120   0     120       W   NSW
# 14314  GW    40   1      40       W   VIC
# 14557  GW    -8   0       8       W   NSW
# 14675  GW    42   1      42       W   VIC
# 14915  GW   -32   0      32       W   NSW
# 15060  GW     3   0      -3       L   NSW
# 15213  GW   -16   1     -16       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.op == 'GW') & (merge_ft.venue == 'M.C.G.')].tail(6)
# Out:
#        year         team  tm_pts    opp_team  op_pts   venue  tm  op  hvar  \
# 14314  2013  Collingwood     106  GWS Giants      66  M.C.G.  CO  GW    40
# 14675  2015  Collingwood     119  GWS Giants      77  M.C.G.  CO  GW    42
# 15213  2018  Collingwood      79  GWS Giants      95  M.C.G.  CO  GW   -16
#
#        lr  tm_var outcome state
# 14314   1      40       W   VIC
# 14675   1      42       W   VIC
# 15213   1     -16       L   VIC

# %% [markdown]
# ### Collingwood at the MCG in 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.venue == 'M.C.G.')&(merge_ft.year == 2018) ]
# Out:
#        year         team  tm_pts         opp_team  op_pts   venue  tm  op  \
# 15205  2018  Collingwood      67         Hawthorn     101  M.C.G.  CO  HA
# 15213  2018  Collingwood      79       GWS Giants      95  M.C.G.  CO  GW
# 15219  2018  Collingwood     100          Carlton      76  M.C.G.  CO  CA
# 15245  2018  Collingwood     101         Essendon      52  M.C.G.  CO  ES
# 15253  2018  Collingwood      70         Richmond     113  M.C.G.  CO  RI
# 15272  2018  Collingwood      45          Geelong      66  M.C.G.  CO  GE
# 15297  2018  Collingwood     138        Fremantle      77  M.C.G.  CO  FR
# 15305  2018  Collingwood     133        Melbourne      91  M.C.G.  CO  ME
# 15317  2018  Collingwood      79          Carlton      59  M.C.G.  CO  CA
# 15334  2018  Collingwood      78         Essendon      62  M.C.G.  CO  ES
# 15342  2018  Collingwood      67       West Coast     102  M.C.G.  CO  WC
# 15346  2018  Collingwood     130  North Melbourne      64  M.C.G.  CO  NM
# 15355  2018  Collingwood      77         Richmond     105  M.C.G.  CO  RI
# 15382  2018  Collingwood     115    Port Adelaide      64  M.C.G.  CO  PA
#
#        hvar  lr  tm_var outcome state
# 15205    34   0     -34       L   VIC
# 15213   -16   1     -16       L   VIC
# 15219   -24   0      24       W   VIC
# 15245    49   1      49       W   VIC
# 15253   -43   1     -43       L   VIC
# 15272   -21   1     -21       L   VIC
# 15297    61   1      61       W   VIC
# 15305   -42   0      42       W   VIC
# 15317    20   1      20       W   VIC
# 15334   -16   0      16       W   VIC
# 15342   -35   1     -35       L   VIC
# 15346    66   1      66       W   VIC
# 15355    28   0     -28       L   VIC
# 15382    51   1      51       W   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.venue == 'M.C.G.')&(merge_ft.year == 2018)].median()
# Out:
# year      2018.0
# tm_pts      79.0
# op_pts      76.5
# hvar         2.0
# lr           1.0
# tm_var      18.0
# dtype: float64

# %% [markdown]
# ### GWS' performances in Victoria: 2017 and 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year >= 2017)&(merge_ft.state == 'VIC')]
# Out:
#        year        team  tm_pts          opp_team  op_pts          venue  tm  \
# 15048  2017  GWS Giants      85          St Kilda     108      Docklands  GW
# 15094  2017  GWS Giants      70           Carlton      71      Docklands  GW
# 15144  2017  GWS Giants      45          Richmond      64         M.C.G.  GW
# 15165  2017  GWS Giants     105  Western Bulldogs      57      Docklands  GW
# 15187  2017  GWS Giants      59           Geelong     103  Kardinia Park  GW
# 15199  2017  GWS Giants      67          Richmond     103         M.C.G.  GW
# 15213  2018  GWS Giants      95       Collingwood      79         M.C.G.  GW
# 15238  2018  GWS Giants      73          St Kilda      73      Docklands  GW
# 15255  2018  GWS Giants      32           Geelong      93  Kardinia Park  GW
# 15369  2018  GWS Giants     151           Carlton      46      Docklands  GW
# 15397  2018  GWS Giants      57         Melbourne     102         M.C.G.  GW
#
#        op  hvar  lr  tm_var outcome state
# 15048  SK    23   0     -23       L   VIC
# 15094  CA     1   0      -1       L   VIC
# 15144  RI    19   0     -19       L   VIC
# 15165  WB   -48   0      48       W   VIC
# 15187  GE    44   0     -44       L   VIC
# 15199  RI    36   0     -36       L   VIC
# 15213  CO   -16   0      16       W   VIC
# 15238  SK     0   0       0       D   VIC
# 15255  GE    61   0     -61       L   VIC
# 15369  CA  -105   0     105       W   VIC
# 15397  ME    45   0     -45       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year >= 2017)&(merge_ft.state == 'VIC')].median()
# Out:
# year      2017.0
# tm_pts      70.0
# op_pts      79.0
# hvar        19.0
# lr           0.0
# tm_var     -19.0
# dtype: float64

# %% [markdown]
# ### GWS' outside NSW in 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year > 2017)&(merge_ft.state != 'NSW')]
# Out:
#        year        team  tm_pts          opp_team  op_pts           venue  tm  \
# 15207  2018  GWS Giants     133  Western Bulldogs      51     Manuka Oval  GW
# 15213  2018  GWS Giants      95       Collingwood      79          M.C.G.  GW
# 15229  2018  GWS Giants      82         Fremantle      51     Manuka Oval  GW
# 15238  2018  GWS Giants      73          St Kilda      73       Docklands  GW
# 15255  2018  GWS Giants      32           Geelong      93   Kardinia Park  GW
# 15275  2018  GWS Giants      69   North Melbourne     112  Bellerive Oval  GW
# 15298  2018  GWS Giants      97          Adelaide      81   Adelaide Oval  GW
# 15315  2018  GWS Giants     109          Brisbane      82           Gabba  GW
# 15335  2018  GWS Giants      75        West Coast      86   Perth Stadium  GW
# 15353  2018  GWS Giants      80     Port Adelaide      58   Adelaide Oval  GW
# 15369  2018  GWS Giants     151           Carlton      46       Docklands  GW
# 15376  2018  GWS Giants     106          Adelaide      92     Manuka Oval  GW
# 15397  2018  GWS Giants      57         Melbourne     102          M.C.G.  GW
#
#        op  hvar  lr  tm_var outcome state
# 15207  WB    82   1      82       W   ACT
# 15213  CO   -16   0      16       W   VIC
# 15229  FR    31   1      31       W   ACT
# 15238  SK     0   0       0       D   VIC
# 15255  GE    61   0     -61       L   VIC
# 15275  NM    43   0     -43       L   TAS
# 15298  AD   -16   0      16       W    SA
# 15315  BR   -27   0      27       W   QLD
# 15335  WC    11   0     -11       L    WA
# 15353  PA   -22   0      22       W    SA
# 15369  CA  -105   0     105       W   VIC
# 15376  AD    14   1      14       W   ACT
# 15397  ME    45   0     -45       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year > 2017)&(merge_ft.state != 'NSW')].median()
# Out:
# year      2018.0
# tm_pts      82.0
# op_pts      81.0
# hvar        11.0
# lr           0.0
# tm_var      16.0
# dtype: float64
