# %%
import os 
os.getcwd()
# Out:
# '/Users/stevegabriel/data_projects/sports_data/afl_dataexploration'

# %%
import pandas as pd

# %%
updated = pd.read_csv("enh_2_aflresults_long.csv", sep =',')

# %% [markdown]
# ### This dataset includes all matches from the start of the 1897 season up to the second week of 2018 finals series

# %%
updated.tail()
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts     opp_team  op_pts  \
# 30803       15402  2018  QF  final   West Coast      86  Collingwood      70
# 30804       15403  2018  SF  final     Hawthorn      71    Melbourne     104
# 30805       15403  2018  SF  final    Melbourne     104     Hawthorn      71
# 30806       15404  2018  SF  final  Collingwood      69   GWS Giants      59
# 30807       15404  2018  SF  final   GWS Giants      59  Collingwood      69
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 30803  Perth Stadium  WC  CO    16   1      16       W    WA
# 30804         M.C.G.  HA  ME    33   0     -33       L   VIC
# 30805         M.C.G.  ME  HA    33   1      33       W   VIC
# 30806         M.C.G.  CO  GW    10   1      10       W   VIC
# 30807         M.C.G.  GW  CO    10   0     -10       L   VIC

# %% [markdown]
# ### Next week's Preliminary finals are:
# * Friday 21 September: Richmond v Collingwood
# * Saturday 22 September: West Coast v Melbourne

# %% [markdown]
# ### There are now 4 possible Grand Final match-ups:
# * Collingwood v West Coast
# * Collingwood v Melbourne
# * Melbourne v Richmond
# * Richmond v West Coast

# %% [markdown]
# ### Historical finals between these pairs:

# %% [markdown]
# ### 1. Collingwood v West Coast

# %%
updated.iloc[:,:][(updated.tm == 'CO')&(updated.op == 'WC')&(updated.type == 'final')]
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts    opp_team  op_pts  \
# 20240       10121  1990  QF  final  Collingwood      90  West Coast      90
# 20245       10123  1990  QF  final  Collingwood     126  West Coast      67
# 21593       10797  1994  QF  final  Collingwood      80  West Coast      82
# 26405       13203  2007  SF  final  Collingwood      93  West Coast      74
# 27902       13952  2011  QF  final  Collingwood      82  West Coast      62
# 28325       14163  2012  SF  final  Collingwood      73  West Coast      60
# 30802       15402  2018  QF  final  Collingwood      70  West Coast      86
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 20240  Waverley Park  CO  WC     0   0       0       D   VIC
# 20245  Waverley Park  CO  WC    59   1      59       W   VIC
# 21593       W.A.C.A.  CO  WC     2   0      -2       L    WA
# 26405        Subiaco  CO  WC    19   1      19       W    WA
# ...

# %% [markdown]
# #### We see that in finals the results have been:
#     * Collingwood 4
#     * West Coast 2
#     * Draws 1

# %% [markdown]
# #### The first Collingwood v West Coast final was a QF in 1990 at VFL Park (Waverley) that resulted in a 90-90 draw.

# %% [markdown]
# ### 2. Collingwood v Melbourne

# %% [markdown]
# #### All finals

# %%
updated.iloc[:,:][(updated.tm == 'CO')&(updated.op == 'ME')&(updated.type == 'final')]
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts   opp_team  op_pts  \
# 113            57  1897  SF  final  Collingwood      51  Melbourne      47
# 4400         2201  1925  PF  final  Collingwood      63  Melbourne      26
# 4623         2312  1926  SF  final  Collingwood      84  Melbourne      95
# 4626         2314  1926  GF  final  Collingwood      62  Melbourne     119
# 5069         2535  1928  SF  final  Collingwood      62  Melbourne      62
# 5070         2536  1928  SF  final  Collingwood      68  Melbourne      64
# 7086         3544  1937  PF  final  Collingwood     107  Melbourne      52
# 7533         3767  1939  SF  final  Collingwood      90  Melbourne     104
# 7536         3769  1939  GF  final  Collingwood      95  Melbourne     148
# 9029         4515  1946  PF  final  Collingwood     100  Melbourne     113
# 9501         4751  1948  PF  final  Collingwood     101  Melbourne     166
# ...

# %%
cm_finals = updated.iloc[:,:][(updated.tm == 'CO')&(updated.op == 'ME')&(updated.type == 'final')]
cm_finals['outcome'].value_counts()
# Out:
# L    16
# W     5
# D     1
# Name: outcome, dtype: int64

# %% [markdown]
# #### Spanning 1897 to 1989, Coll-Melb finals results have been:
#     * Melbourne 16
#     * Collingwood 5
#     * Draws 1

# %% [markdown]
# #### All Grand Finals between Collingwood & Melbourne

# %%
co_me = updated.iloc[:,:][(updated.tm == 'CO')&(updated.op == 'ME')&(updated.rnd == 'GF')]

# %%
co_me
# Out:
#        Unnamed: 0  year rnd   type         team  tm_pts   opp_team  op_pts  \
# 4626         2314  1926  GF  final  Collingwood      62  Melbourne     119
# 7536         3769  1939  GF  final  Collingwood      95  Melbourne     148
# 11096        5549  1955  GF  final  Collingwood      36  Melbourne      64
# 11320        5661  1956  GF  final  Collingwood      48  Melbourne     121
# 11769        5885  1958  GF  final  Collingwood      82  Melbourne      64
# 12216        6109  1960  GF  final  Collingwood      14  Melbourne      62
# 13114        6558  1964  GF  final  Collingwood      60  Melbourne      64
#
#         venue  tm  op  hvar  lr  tm_var outcome state
# 4626   M.C.G.  CO  ME    57   0     -57       L   VIC
# 7536   M.C.G.  CO  ME    53   0     -53       L   VIC
# 11096  M.C.G.  CO  ME    28   0     -28       L   VIC
# 11320  M.C.G.  CO  ME    73   0     -73       L   VIC
# 11769  M.C.G.  CO  ME    18   1      18       W   VIC
# ...

# %%
co_me['outcome'].value_counts()
# Out:
# L    6
# W    1
# Name: outcome, dtype: int64

# %% [markdown]
# #### The seven Collingwood - Melb grand finals span 1926 to 1964, with Melbourne winning six.

# %% [markdown]
# ### 3.  Melbourne v Richmond

# %%
updated.iloc[:,:][(updated.tm == 'ME')&(updated.op == 'RI')&(updated.type == 'final')]
# Out:
#       Unnamed: 0  year rnd   type       team  tm_pts  opp_team  op_pts  \
# 7757        3879  1940  SF  final  Melbourne     101  Richmond     107
# 7761        3881  1940  GF  final  Melbourne     107  Richmond      68
#
#        venue  tm  op  hvar  lr  tm_var outcome state
# 7757  M.C.G.  ME  RI     6   0      -6       L   VIC
# 7761  M.C.G.  ME  RI    39   1      39       W   VIC

# %% [markdown]
# #### Both Melbourne - Richmond finals were in 1940. The GF was won by Melbourne by 39.

# %% [markdown]
# ### 4.  Richmond v West Coast

# %%
updated.iloc[:,:][(updated.tm == 'RI')&(updated.op == 'WC')&(updated.type == 'final')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, year, rnd, type, team, tm_pts, opp_team, op_pts, venue, tm, op, hvar, lr, tm_var, outcome, state]
# Index: []

# %% [markdown]
# ## Melbourne in finals

# %%
mel_fins = updated.iloc[:,:][(updated.tm == 'ME')&(updated.type == 'final')]

# %%
mel_fins.head()
# Out:
#      Unnamed: 0  year rnd   type       team  tm_pts     opp_team  op_pts  \
# 112          57  1897  SF  final  Melbourne      47  Collingwood      51
# 119          60  1897  SF  final  Melbourne      37      Geelong      46
# 123          62  1897  SF  final  Melbourne       8     Essendon      14
# 538         270  1900  SF  final  Melbourne      45     Essendon      43
# 540         271  1900  GF  final  Melbourne      34      Fitzroy      30
#
#               venue  tm  op  hvar  lr  tm_var outcome state
# 112          M.C.G.  ME  CO     4   0      -4       L   VIC
# 119    Brunswick St  ME  GE     9   0      -9       L   VIC
# 123       Lake Oval  ME  ES     6   0      -6       L   VIC
# 538       Lake Oval  ME  ES     2   1       2       W   VIC
# 540  East Melbourne  ME  FI     4   1       4       W   VIC

# %%
mel_fins.sort_values(by=['tm_pts']).head(20)
# Out:
#        Unnamed: 0  year rnd   type       team  tm_pts          opp_team  \
# 123            62  1897  SF  final  Melbourne       8          Essendon
# 4401         2201  1925  PF  final  Melbourne      26       Collingwood
# 540           271  1900  GF  final  Melbourne      34           Fitzroy
# 119            60  1897  SF  final  Melbourne      37           Geelong
# 4624         2313  1926  PF  final  Melbourne      42          Essendon
# 9958         4980  1950  SF  final  Melbourne      44           Geelong
# 538           270  1900  SF  final  Melbourne      45          Essendon
# 112            57  1897  SF  final  Melbourne      47       Collingwood
# 823           412  1902  SF  final  Melbourne      51          Essendon
# 10872        5437  1954  GF  final  Melbourne      51  Western Bulldogs
# 21601       10801  1994  PF  final  Melbourne      52        West Coast
# 7087         3544  1937  PF  final  Melbourne      52       Collingwood
# ...

# %%
mel_fins.sort_values(by=['tm_var']).head(20)
# Out:
#        Unnamed: 0  year rnd   type       team  tm_pts          opp_team  \
# 19611        9806  1988  GF  final  Melbourne      56          Hawthorn
# 21601       10801  1994  PF  final  Melbourne      52        West Coast
# 19926        9964  1989  SF  final  Melbourne      90           Geelong
# 9031         4516  1946  GF  final  Melbourne      87          Essendon
# 23822       11912  2000  GF  final  Melbourne      75          Essendon
# 7087         3544  1937  PF  final  Melbourne      52       Collingwood
# 25659       12830  2005  EF  final  Melbourne      61           Geelong
# 10872        5437  1954  GF  final  Melbourne      51  Western Bulldogs
# 9958         4980  1950  SF  final  Melbourne      44           Geelong
# 20592       10297  1991  SF  final  Melbourne      79        West Coast
# 4401         2201  1925  PF  final  Melbourne      26       Collingwood
# 9499         4750  1948  SF  final  Melbourne      58          Essendon
# ...

# %% [markdown]
# ## WC in finals

# %%
wc_fins = updated.iloc[:,:][(updated.tm == 'WC')&(updated.type == 'final')]

# %%
wc_fins.sort_values(by=['tm_var'], ascending = False).head(10)
# Out:
#        Unnamed: 0  year rnd   type        team  tm_pts          opp_team  \
# 28321       14161  2012  EF  final  West Coast     162   North Melbourne
# 21602       10802  1994  GF  final  West Coast     143           Geelong
# 26037       13019  2006  SF  final  West Coast     113  Western Bulldogs
# 21600       10801  1994  PF  final  West Coast     117         Melbourne
# 22328       11165  1996  QF  final  West Coast     125           Carlton
# 21242       10622  1993  EF  final  West Coast     120   North Melbourne
# 20593       10297  1991  SF  final  West Coast     117         Melbourne
# 20936       10469  1992  SF  final  West Coast     133           Geelong
# 29554       14778  2015  QF  final  West Coast      96          Hawthorn
# 20247       10124  1990  SF  final  West Coast     130         Melbourne
#
#        op_pts          venue  tm  op  hvar  lr  tm_var outcome state
# 28321      66        Subiaco  WC  NM    96   1      96       W    WA
# ...

# %% [markdown]
# #### There have been no finals between Richmond and West Coast.
