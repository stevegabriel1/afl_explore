# %% [markdown]
# ### Data file preparation steps:
#
#     * The raw text file from https://afltables.com/afl/stats/biglists/bg3.txt is saved as llist.txt
#     * The file llist.txt is then processed through the bash script file a_updater.sh to add commas at the appropriate locations and make other modifications, by typing ./a_updater into Terminal - ready to be imported from within Jupyter.

# %% [markdown]
# # Post week 1 of 2018 finals series

# %%
#%%html
#<img src="img/ess_stk.png" alt="Drawing" align="left" style="width: 800px;"/>

# %%
import os 
os.getcwd()
# Out:
# '/Users/stevegabriel/data_projects/sports_data/afl_dataexploration'

# %%
import pandas as pd

# %%
cols = ['seq','date','rnd','team1','gls_1','bhs_1','pts_1','team2','gls_2','bhs_2','pts_2','venue']

# %% [markdown]
# #### The file will contain all matches starting from the first ever VFL game in 1987 - more than fifteen thousand games.

# %%
upd_round = pd.read_csv("newlist.csv", names = cols)
trans = upd_round

# %%
# Modify index to start at 1 
trans.index += 1
trans.tail()
# Out:
#          seq         date  rnd       team1  gls_1  bhs_1  pts_1  \
# 15398  15398  26-Aug-2018  R23    St Kilda     14     10     94
# 15399  15399   6-Sep-2018   QF    Richmond     13     17     95
# 15400  15400   7-Sep-2018   EF   Melbourne     10     15     75
# 15401  15401   8-Sep-2018   EF   GW Sydney     10     19     79
# 15402  15402   8-Sep-2018   QF  West Coast     12     14     86
#
#                  team2  gls_2  bhs_2  pts_2          venue
# 15398  North Melbourne     17     15    117      Docklands
# 15399         Hawthorn      9     10     64         M.C.G.
# 15400          Geelong      6     10     46         M.C.G.
# 15401           Sydney      4      6     30         S.C.G.
# 15402      Collingwood     10     10     70  Perth Stadium

# %% [markdown]
# #### Shown above, the most four finals matches played on the weekend.

# %% [markdown]
# ### Adding additional information including state, and addition team names as two letter codes

# %%
# Add states
nsw = ['S.C.G.','Sydney Showground','Stadium Australia','Blacktown','Albury']
qld = ['Gabba','Carrara','Cazaly\'s Stadium','Brisbane Exhibition']
sa = ['Football Park','Adelaide Oval']
wa = ['W.A.C.A.','Perth Stadium','Subiaco']
nt = ['Marrara Oval','Traeger Park']
tas = ['York Park','Bellerive Oval','North Hobart']
act = ['Manuka Oval','Bruce Stadium']
intl = ['Wellington','Jiangwan Stadium']

# %%
def locations(x):
    if x in nsw:
        return "NSW"
    elif x in sa:
        return "SA"
    elif x in wa:
        return "WA"
    elif x in nt:
        return "NT"
    elif x in tas:
        return "TAS"
    elif x in intl:
        return "INTL"
    elif x in act:
        return "ACT"
    elif x in qld:
        return "QLD"
    else: 
        return "VIC"

# %%
trans["state"] = trans["venue"].apply(locations)
trans["state"].value_counts()
# Out:
# VIC     13034
# WA        641
# SA        573
# NSW       512
# QLD       474
# TAS        91
# ACT        48
# NT         24
# INTL        5
# Name: state, dtype: int64

# %%
## 1. HVAR & AGGR
trans['hvar'] = trans['pts_1'] - trans['pts_2']
trans['aggr'] = trans['pts_1'] + trans['pts_2']

# %%
## 2. YEAR & MONTH
import time
import datetime

# %%
trans['date'] = pd.to_datetime(trans['date'])
trans['year'], trans['month'] = trans['date'].dt.year, trans['date'].dt.month

# %%
## 3. ABBREVIATED CLUB NAMES
adelaide = ['Adelaide']
brisbane = ['Brisbane Bears','Brisbane Lions']
carlton = ['Carlton']
collingwood = ['Collingwood']
essendon = ['Essendon']
fitzroy = ['Fitzroy']
footscray = ['Footscray']
fremantle = ['Fremantle']
geelong = ['Geelong']
gold_coast = ['Gold Coast']
gws = ['GW Sydney']
hawthorn = ['Hawthorn']
melbourne = ['Melbourne']
north_melbourne = ['North Melbourne','Kangaroos']
port_adelaide = ['Port Adelaide']
richmond = ['Richmond']
south_melbourne = ['South Melbourne']
st_kilda = ['St Kilda']
sydney = ['Sydney']
west_coast = ['West Coast']
western_bulldogs = ['Western Bulldogs', 'Footscray']
university = ['University']

# %%
def team_shorten(x):
    if x in adelaide:
        return "AD"
    elif x in brisbane:
        return "BR"
    elif x in carlton:
        return "CA"
    elif x in collingwood:
        return "CO"
    elif x in essendon:
        return "ES"
    elif x in fitzroy:
        return "FI"
    elif x in fremantle:
        return "FR"
    elif x in geelong:
        return "GE"
    elif x in gold_coast:
        return "GC"
    elif x in gws:
        return "GW"
    elif x in hawthorn:
        return "HA"
    elif x in melbourne:
        return "ME"
    elif x in north_melbourne:
        return "NM"
    elif x in port_adelaide:
        return "PA"
    elif x in richmond:
        return "RI"
    elif x in south_melbourne:
        return "SM"
    elif x in st_kilda:
        return "SK"
    elif x in sydney:
        return "SY"
    elif x in west_coast:
        return "WC"
    elif x in western_bulldogs:
        return "WB"
    elif x in university:
        return "UN"
    else: 
        return "NOT_FOUND"

# %%
trans["t1"] = trans["team1"].apply(team_shorten)
trans["t2"] = trans["team2"].apply(team_shorten)

# %%
trans['t1'].value_counts().sum()
# Out:
# 15402

# %% [markdown]
# ##  FIX TEAM NAMES ANOMOLIES

# %% [markdown]
# * Merge Footscray & Western Bulldogs as **Western Bulldogs**
# * Merge North Melbourne with Kangaroos as **North Melbourne**
# * Merge Brisbane Lions with Brisbane Bears as **Brisbane**
# * Leave Sydney and **South Melbourne** as separate
# * Leave **Fitzroy** as separate
# * Modify GW Sydney to **GWS Giants**

# %%
# Function from Analytics Vidhya
def coding(col, codeDict):
  colCoded = pd.Series(col, copy=True)
  for key, value in codeDict.items():
    colCoded.replace(key, value, inplace=True)
  return colCoded

# %%
trans["team1"] = coding(trans["team1"], {'Footscray':'Western Bulldogs'})
trans["team2"] = coding(trans["team2"], {'Footscray':'Western Bulldogs'})
trans["team1"] = coding(trans["team1"], {'Kangaroos':'North Melbourne'})
trans["team2"] = coding(trans["team2"], {'Kangaroos':'North Melbourne'})
trans["team1"] = coding(trans["team1"], {'Brisbane Bears':'Brisbane','Brisbane Lions':'Brisbane'})
trans["team2"] = coding(trans["team2"], {'Brisbane Bears':'Brisbane','Brisbane Lions':'Brisbane'})
trans["team1"] = coding(trans["team1"], {'GW Sydney':'GWS Giants'})
trans["team2"] = coding(trans["team2"], {'GW Sydney':'GWS Giants'})

# %%
trans["team2"].value_counts()
# Out:
# Collingwood         1274
# Carlton             1251
# Essendon            1222
# Geelong             1219
# St Kilda            1190
# Melbourne           1190
# Richmond            1118
# North Melbourne      986
# Hawthorn             979
# Western Bulldogs     975
# Fitzroy              960
# South Melbourne      788
# Sydney               432
# West Coast           376
# Brisbane             359
# Adelaide             325
# Fremantle            273
# Port Adelaide        254
# Gold Coast            88
# GWS Giants            80
# University            63
# Name: team2, dtype: int64

# %% [markdown]
# #### The dataframe with the additional column. Currently it has one game per row.

# %%
trans.head(10)
# Out:
#     seq       date rnd            team1  gls_1  bhs_1  pts_1        team2  \
# 1     1 1897-05-08  R1          Fitzroy      6     13     49      Carlton
# 2     2 1897-05-08  R1      Collingwood      5     11     41     St Kilda
# 3     3 1897-05-08  R1          Geelong      3      6     24     Essendon
# 4     4 1897-05-08  R1  South Melbourne      3      9     27    Melbourne
# 5     5 1897-05-15  R2  South Melbourne      6      4     40      Carlton
# 6     6 1897-05-15  R2         Essendon      4      6     30  Collingwood
# 7     7 1897-05-15  R2         St Kilda      3      8     26      Fitzroy
# 8     8 1897-05-15  R2        Melbourne      9     10     64      Geelong
# 9     9 1897-05-22  R3      Collingwood      6      5     41      Geelong
# 10   10 1897-05-22  R3          Fitzroy      5      9     39    Melbourne
#
#     gls_2  bhs_2  pts_2           venue state  hvar  aggr  year  month  t1  t2
# 1       2      4     16    Brunswick St   VIC    33    65  1897      5  FI  CA
# 2       2      4     16   Victoria Park   VIC    25    57  1897      5  CO  SK
# 3       7      5     47      Corio Oval   VIC   -23    71  1897      5  GE  ES
# 4       6      8     44       Lake Oval   VIC   -17    71  1897      5  SM  ME
# 5       5      6     36       Lake Oval   VIC     4    76  1897      5  SM  CA
# 6       8      2     50  East Melbourne   VIC   -20    80  1897      5  ES  CO
# 7      10      6     66   Junction Oval   VIC   -40    92  1897      5  SK  FI
# 8       3      1     19          M.C.G.   VIC    45    83  1897      5  ME  GE
# 9       5      7     37   Victoria Park   VIC     4    78  1897      5  CO  GE
# 10      7      8     50    Brunswick St   VIC   -11    89  1897      5  FI  ME

# %% [markdown]
# ## ALL DRAWS (BOOLEAN)

# %%
def reg_draw(hvar):
    if hvar == 0:
        return 1
    else: return 0

# %%
trans["draw_rt"] = trans["hvar"].apply(reg_draw)

# %%
trans['draw_rt'].value_counts()
# Out:
# 0    15244
# 1      158
# Name: draw_rt, dtype: int64

# %% [markdown]
# ### The 158 draws above, represent the VFL/AFL games that have concluded in a draw result

# %% [markdown]
# ### The two ET (extra-time) draws below are statistically relevent, since they also ended regular full-time with both teams on the same score. However extra-time was applied to create a result, due to finals constraints.

# %%
def et_draw(seq):
    if seq == 10794:
        return 1
    elif seq == 13203:
        return 1
    else: return 0

# %%
trans["etime_draw"] = trans["seq"].apply(et_draw)
trans['etime_draw'].value_counts()
# Out:
# 0    15400
# 1        2
# Name: etime_draw, dtype: int64

# %%
### Add the two columns
trans['draws_all']  = trans['draw_rt'] + trans['etime_draw']
trans['draws_all'].value_counts()
# Out:
# 0    15242
# 1      160
# Name: draws_all, dtype: int64

# %%
# Check
trans.iloc[:,:][(trans.etime_draw == 1)]
# Out:
#          seq       date rnd            team1  gls_1  bhs_1  pts_1       team2  \
# 10794  10794 1994-09-10  QF  North Melbourne     15     24    114    Hawthorn
# 13203  13203 2007-09-14  SF      Collingwood     13     15     93  West Coast
#
#        gls_2  bhs_2    ...      state hvar aggr  year  month  t1  t2 draw_rt  \
# 10794     13     13    ...        VIC   23  205  1994      9  NM  HA       0
# 13203     10     14    ...         WA   19  167  2007      9  CO  WC       0
#
#       etime_draw  draws_all
# 10794          1          1
# 13203          1          1
#
# [2 rows x 22 columns]

# %%
# 6. GAME CATEGORY
finals = ['EF','QF','SF','PF','GF']

# %%
def game_cat(x):
    if x in finals:
        return "final"
    else: 
        return "reg_season"

# %%
trans["type"] = trans["rnd"].apply(game_cat)

# %%
trans['type'].value_counts()
# Out:
# reg_season    14752
# final           650
# Name: type, dtype: int64

# %% [markdown]
# ### So, there have been 650 finals up to the end of week one of 2018 finals series.

# %%
def grouping_2K(seq):
    n=500
    if seq <= 4*n:
        return 1
    elif seq <= 8*n:
        return 2
    elif seq <= 12*n:
        return 3
    elif seq <= 16*n:
        return 4
    elif seq <= 20*n:
        return 5
    elif seq <= 24*n:
        return 6
    elif seq <= 28*n:
        return 7
    else: return 8

# %%
trans["grp_2K"] = trans["seq"].apply(grouping_2K)

# %%
def grouping_1K(seq):
    n=1000
    if seq <= n:
        return 1
    elif seq <= 2*n:
        return 2
    elif seq <= 3*n:
        return 3
    elif seq <= 4*n:
        return 4
    elif seq <= 5*n:
        return 5
    elif seq <= 6*n:
        return 6
    elif seq <= 7*n:
        return 7
    elif seq <= 8*n:
        return 8
    elif seq <= 9*n:
        return 9
    elif seq <= 10*n:
        return 10
    elif seq <= 11*n:
        return 11
    elif seq <= 12*n:
        return 12
    elif seq <= 13*n:
        return 13
    elif seq <= 14*n:
        return 14
    elif seq <= 15*n:
        return 15
    else: return 16

# %%
trans["grp_1K"] = trans["seq"].apply(grouping_1K)

# %%
# Export the data frame for use in afl draws EDA
trans.to_csv('all_afl_wide.csv')

# %% [markdown]
# ## ADD res1 and res2 columns as categorical 1 = win, 2 = loss, 3 = draw based on hvar (ignoring the two extra time finals)

# %%
def result_cat_h(hvar):
    if hvar > 0:
        return 1
    elif hvar < 0:
        return 2
    else: return 3

# %%
def result_cat_a(hvar):
    if hvar > 0:
        return 2
    elif hvar < 0:
        return 1
    else: return 3

# %%
trans['res1'] = trans['hvar'].apply(result_cat_h)
trans['res2'] = trans['hvar'].apply(result_cat_a)

# %%
trans.tail(9)
# Out:
#          seq       date  rnd       team1  gls_1  bhs_1  pts_1  \
# 15394  15394 2018-08-25  R23     Carlton      8     13     61
# 15395  15395 2018-08-25  R23      Sydney     10     14     74
# 15396  15396 2018-08-26  R23    Brisbane     11      6     72
# 15397  15397 2018-08-26  R23   Melbourne     15     12    102
# 15398  15398 2018-08-26  R23    St Kilda     14     10     94
# 15399  15399 2018-09-06   QF    Richmond     13     17     95
# 15400  15400 2018-09-07   EF   Melbourne     10     15     75
# 15401  15401 2018-09-08   EF  GWS Giants     10     19     79
# 15402  15402 2018-09-08   QF  West Coast     12     14     86
#
#                  team2  gls_2  bhs_2  ...   t1  t2 draw_rt  etime_draw  \
# 15394         Adelaide     26      9  ...   CA  AD       0           0
# 15395         Hawthorn     12     11  ...   SY  HA       0           0
# 15396       West Coast     14     14  ...   BR  WC       0           0
# 15397       GWS Giants      8      9  ...   ME  GW       0           0
# 15398  North Melbourne     17     15  ...   SK  NM       0           0
# 15399         Hawthorn      9     10  ...   RI  HA       0           0
# 15400          Geelong      6     10  ...   ME  GE       0           0
# 15401           Sydney      4      6  ...   GW  SY       0           0
# 15402      Collingwood     10     10  ...   WC  CO       0           0
#
#        draws_all        type  grp_2K grp_1K res1  res2
# 15394          0  reg_season       8     16    2     1
# 15395          0  reg_season       8     16    2     1
# 15396          0  reg_season       8     16    2     1
# 15397          0  reg_season       8     16    1     2
# 15398          0  reg_season       8     16    2     1
# 15399          0       final       8     16    1     2
# 15400          0       final       8     16    1     2
# 15401          0       final       8     16    1     2
# 15402          0       final       8     16    1     2
#
# [9 rows x 27 columns]

# %%
trans.shape
# Out:
# (15402, 27)

# %% [markdown]
# ### Export enhanced results 1897-2018 with 27 columns

# %%
trans.to_csv('enh_1_aflresults.csv')

# %% [markdown]
# ## STAGE TWO
# ## 9. Reduce and re-order the data frame to prepare for for Long format

# %%
tracker = trans
tracker = tracker[['year', 'rnd','type','team1','pts_1','team2','pts_2','venue','t1','t2','hvar']]
tracker.tail()
# Out:
#        year  rnd        type       team1  pts_1            team2  pts_2  \
# 15398  2018  R23  reg_season    St Kilda     94  North Melbourne    117
# 15399  2018   QF       final    Richmond     95         Hawthorn     64
# 15400  2018   EF       final   Melbourne     75          Geelong     46
# 15401  2018   EF       final  GWS Giants     79           Sydney     30
# 15402  2018   QF       final  West Coast     86      Collingwood     70
#
#                venue  t1  t2  hvar
# 15398      Docklands  SK  NM   -23
# 15399         M.C.G.  RI  HA    31
# 15400         M.C.G.  ME  GE    29
# 15401         S.C.G.  GW  SY    49
# 15402  Perth Stadium  WC  CO    16

# %% [markdown]
# ### Create two new columns with values 1 and 0 for the two subsets

# %%
tracker['subset_1'] = 1
tracker['subset_2'] = 0
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tracker.tail(9)
# Out:
#        year  rnd        type       team1  pts_1            team2  pts_2  \
# 15394  2018  R23  reg_season     Carlton     61         Adelaide    165
# 15395  2018  R23  reg_season      Sydney     74         Hawthorn     83
# 15396  2018  R23  reg_season    Brisbane     72       West Coast     98
# 15397  2018  R23  reg_season   Melbourne    102       GWS Giants     57
# 15398  2018  R23  reg_season    St Kilda     94  North Melbourne    117
# 15399  2018   QF       final    Richmond     95         Hawthorn     64
# 15400  2018   EF       final   Melbourne     75          Geelong     46
# 15401  2018   EF       final  GWS Giants     79           Sydney     30
# 15402  2018   QF       final  West Coast     86      Collingwood     70
#
#                venue  t1  t2  hvar  subset_1  subset_2
# 15394      Docklands  CA  AD  -104         1         0
# 15395         S.C.G.  SY  HA    -9         1         0
# 15396          Gabba  BR  WC   -26         1         0
# 15397         M.C.G.  ME  GW    45         1         0
# 15398      Docklands  SK  NM   -23         1         0
# 15399         M.C.G.  RI  HA    31         1         0
# 15400         M.C.G.  ME  GE    29         1         0
# 15401         S.C.G.  GW  SY    49         1         0
# 15402  Perth Stadium  WC  CO    16         1         0

# %%
droplist_1 = ['subset_2']
droplist_2 = ['subset_1']

# %%
left_team = tracker.drop(droplist_1, axis = 1)
right_team = tracker.drop(droplist_2, axis = 1)

# %%
left_team.shape
# Out:
# (15402, 12)

# %%
right_team.shape
# Out:
# (15402, 12)

# %% [markdown]
# # Rename columns in each dframe

# %%
left_team.columns = ['year','rnd','type','team','tm_pts','opp_team','op_pts','venue','tm','op','hvar','lr']
right_team.columns = ['year','rnd','type','opp_team','op_pts','team','tm_pts','venue','op','tm','hvar','lr']

# %% [markdown]
# ### Now re-order the second dframe to match columns

# %% [markdown]
# ### Note double brackets to re-order

# %%
right_team = right_team[['year', 'rnd','type','team','tm_pts','opp_team','op_pts','venue','tm','op','hvar','lr']]
right_team.tail()
# Out:
#        year  rnd        type             team  tm_pts    opp_team  op_pts  \
# 15398  2018  R23  reg_season  North Melbourne     117    St Kilda      94
# 15399  2018   QF       final         Hawthorn      64    Richmond      95
# 15400  2018   EF       final          Geelong      46   Melbourne      75
# 15401  2018   EF       final           Sydney      30  GWS Giants      79
# 15402  2018   QF       final      Collingwood      70  West Coast      86
#
#                venue  tm  op  hvar  lr
# 15398      Docklands  NM  SK   -23   0
# 15399         M.C.G.  HA  RI    31   0
# 15400         M.C.G.  GE  ME    29   0
# 15401         S.C.G.  SY  GW    49   0
# 15402  Perth Stadium  CO  WC    16   0

# %%
right_team.tail()
# Out:
#        year  rnd        type             team  tm_pts    opp_team  op_pts  \
# 15398  2018  R23  reg_season  North Melbourne     117    St Kilda      94
# 15399  2018   QF       final         Hawthorn      64    Richmond      95
# 15400  2018   EF       final          Geelong      46   Melbourne      75
# 15401  2018   EF       final           Sydney      30  GWS Giants      79
# 15402  2018   QF       final      Collingwood      70  West Coast      86
#
#                venue  tm  op  hvar  lr
# 15398      Docklands  NM  SK   -23   0
# 15399         M.C.G.  HA  RI    31   0
# 15400         M.C.G.  GE  ME    29   0
# 15401         S.C.G.  SY  GW    49   0
# 15402  Perth Stadium  CO  WC    16   0

# %%
left_team.tail()
# Out:
#        year  rnd        type        team  tm_pts         opp_team  op_pts  \
# 15398  2018  R23  reg_season    St Kilda      94  North Melbourne     117
# 15399  2018   QF       final    Richmond      95         Hawthorn      64
# 15400  2018   EF       final   Melbourne      75          Geelong      46
# 15401  2018   EF       final  GWS Giants      79           Sydney      30
# 15402  2018   QF       final  West Coast      86      Collingwood      70
#
#                venue  tm  op  hvar  lr
# 15398      Docklands  SK  NM   -23   1
# 15399         M.C.G.  RI  HA    31   1
# 15400         M.C.G.  ME  GE    29   1
# 15401         S.C.G.  GW  SY    49   1
# 15402  Perth Stadium  WC  CO    16   1

# %% [markdown]
# ## CONCATENATION

# %% [markdown]
# ### Can now concatenate the two dframes, as in si_week11

# %%
merge_ft = pd.concat([left_team, right_team], axis=0)
merge_ft.head()
# Out:
#    year rnd        type             team  tm_pts   opp_team  op_pts  \
# 1  1897  R1  reg_season          Fitzroy      49    Carlton      16
# 2  1897  R1  reg_season      Collingwood      41   St Kilda      16
# 3  1897  R1  reg_season          Geelong      24   Essendon      47
# 4  1897  R1  reg_season  South Melbourne      27  Melbourne      44
# 5  1897  R2  reg_season  South Melbourne      40    Carlton      36
#
#            venue  tm  op  hvar  lr
# 1   Brunswick St  FI  CA    33   1
# 2  Victoria Park  CO  SK    25   1
# 3     Corio Oval  GE  ES   -23   1
# 4      Lake Oval  SM  ME   -17   1
# 5      Lake Oval  SM  CA     4   1

# %% [markdown]
# #### The new long data frame consisting of 30,000 plus rows:

# %%
merge_ft.shape
# Out:
# (30804, 12)

# %% [markdown]
# # The following is to keep each game together (two rows per game)

# %%
merge_ft.sort_index(inplace=True)
merge_ft.head(10)
# Out:
#    year rnd        type             team  tm_pts         opp_team  op_pts  \
# 1  1897  R1  reg_season          Fitzroy      49          Carlton      16
# 1  1897  R1  reg_season          Carlton      16          Fitzroy      49
# 2  1897  R1  reg_season      Collingwood      41         St Kilda      16
# 2  1897  R1  reg_season         St Kilda      16      Collingwood      41
# 3  1897  R1  reg_season          Geelong      24         Essendon      47
# 3  1897  R1  reg_season         Essendon      47          Geelong      24
# 4  1897  R1  reg_season  South Melbourne      27        Melbourne      44
# 4  1897  R1  reg_season        Melbourne      44  South Melbourne      27
# 5  1897  R2  reg_season  South Melbourne      40          Carlton      36
# 5  1897  R2  reg_season          Carlton      36  South Melbourne      40
#
#            venue  tm  op  hvar  lr
# 1   Brunswick St  FI  CA    33   1
# 1   Brunswick St  CA  FI    33   0
# 2  Victoria Park  CO  SK    25   1
# 2  Victoria Park  SK  CO    25   0
# 3     Corio Oval  GE  ES   -23   1
# 3     Corio Oval  ES  GE   -23   0
# 4      Lake Oval  SM  ME   -17   1
# 4      Lake Oval  ME  SM   -17   0
# 5      Lake Oval  SM  CA     4   1
# 5      Lake Oval  CA  SM     4   0

# %%
merge_ft.tail()
# Out:
#        year rnd   type         team  tm_pts     opp_team  op_pts  \
# 15400  2018  EF  final    Melbourne      75      Geelong      46
# 15401  2018  EF  final       Sydney      30   GWS Giants      79
# 15401  2018  EF  final   GWS Giants      79       Sydney      30
# 15402  2018  QF  final   West Coast      86  Collingwood      70
# 15402  2018  QF  final  Collingwood      70   West Coast      86
#
#                venue  tm  op  hvar  lr
# 15400         M.C.G.  ME  GE    29   1
# 15401         S.C.G.  SY  GW    49   0
# 15401         S.C.G.  GW  SY    49   1
# 15402  Perth Stadium  WC  CO    16   1
# 15402  Perth Stadium  CO  WC    16   0

# %% [markdown]
# ## There are actually 30,804 rows, indexing isn't  sequential

# %% [markdown]
# ## Create team result column

# %%
def neg_hvar(hvar):
        return -1*hvar

# %%
merge_ft["neg_dummy"] = merge_ft['hvar'].apply(neg_hvar)

# %%
merge_ft.tail()
# Out:
#        year rnd   type         team  tm_pts     opp_team  op_pts  \
# 15400  2018  EF  final    Melbourne      75      Geelong      46
# 15401  2018  EF  final       Sydney      30   GWS Giants      79
# 15401  2018  EF  final   GWS Giants      79       Sydney      30
# 15402  2018  QF  final   West Coast      86  Collingwood      70
# 15402  2018  QF  final  Collingwood      70   West Coast      86
#
#                venue  tm  op  hvar  lr  neg_dummy
# 15400         M.C.G.  ME  GE    29   1        -29
# 15401         S.C.G.  SY  GW    49   0        -49
# 15401         S.C.G.  GW  SY    49   1        -49
# 15402  Perth Stadium  WC  CO    16   1        -16
# 15402  Perth Stadium  CO  WC    16   0        -16

# %%
def team_var(hvar):
    if merge_ft['lr'] == 1:
        return hvar
    else: return neg_dummy

# %%
def new_lr(lr):
    if lr == 0:
        return -1
    else: return 1

# %%
merge_ft["new_lr"] = merge_ft['lr'].apply(new_lr)
merge_ft["tm_var"] = merge_ft['new_lr']*merge_ft['hvar']

# %%
merge_ft.tail()
# Out:
#        year rnd   type         team  tm_pts     opp_team  op_pts  \
# 15400  2018  EF  final    Melbourne      75      Geelong      46
# 15401  2018  EF  final       Sydney      30   GWS Giants      79
# 15401  2018  EF  final   GWS Giants      79       Sydney      30
# 15402  2018  QF  final   West Coast      86  Collingwood      70
# 15402  2018  QF  final  Collingwood      70   West Coast      86
#
#                venue  tm  op  hvar  lr  neg_dummy  new_lr  tm_var
# 15400         M.C.G.  ME  GE    29   1        -29       1      29
# 15401         S.C.G.  SY  GW    49   0        -49      -1     -49
# 15401         S.C.G.  GW  SY    49   1        -49       1      49
# 15402  Perth Stadium  WC  CO    16   1        -16       1      16
# 15402  Perth Stadium  CO  WC    16   0        -16      -1     -16

# %% [markdown]
# ### Can now remove the columns new_lr and neg_dummy, which were used to create tm_var

# %%
merge_ft = merge_ft.drop(['neg_dummy', 'new_lr'], axis=1)

# %%
merge_ft.head()
# Out:
#    year rnd        type         team  tm_pts     opp_team  op_pts  \
# 1  1897  R1  reg_season      Fitzroy      49      Carlton      16
# 1  1897  R1  reg_season      Carlton      16      Fitzroy      49
# 2  1897  R1  reg_season  Collingwood      41     St Kilda      16
# 2  1897  R1  reg_season     St Kilda      16  Collingwood      41
# 3  1897  R1  reg_season      Geelong      24     Essendon      47
#
#            venue  tm  op  hvar  lr  tm_var
# 1   Brunswick St  FI  CA    33   1      33
# 1   Brunswick St  CA  FI    33   0     -33
# 2  Victoria Park  CO  SK    25   1      25
# 2  Victoria Park  SK  CO    25   0     -25
# 3     Corio Oval  GE  ES   -23   1     -23

# %% [markdown]
# ### Note that the column 'lr' denotes left right, so there are only two different values (1 denotes left)

# %%
merge_ft['lr'].value_counts()
# Out:
# 1    15402
# 0    15402
# Name: lr, dtype: int64

# %% [markdown]
# ## New function for win/loss/draw (W/L/D)

# %%
def outcome(tm_var):
    if tm_var >= 1:
        return "W"
    elif tm_var <= -1:
        return "L"
    elif tm_var == 0:
        return "D"
    else: return "Unknown"

# %%
merge_ft["outcome"] = merge_ft['tm_var'].apply(outcome)

# %%
merge_ft.head()
# Out:
#    year rnd        type         team  tm_pts     opp_team  op_pts  \
# 1  1897  R1  reg_season      Fitzroy      49      Carlton      16
# 1  1897  R1  reg_season      Carlton      16      Fitzroy      49
# 2  1897  R1  reg_season  Collingwood      41     St Kilda      16
# 2  1897  R1  reg_season     St Kilda      16  Collingwood      41
# 3  1897  R1  reg_season      Geelong      24     Essendon      47
#
#            venue  tm  op  hvar  lr  tm_var outcome
# 1   Brunswick St  FI  CA    33   1      33       W
# 1   Brunswick St  CA  FI    33   0     -33       L
# 2  Victoria Park  CO  SK    25   1      25       W
# 2  Victoria Park  SK  CO    25   0     -25       L
# 3     Corio Oval  GE  ES   -23   1     -23       L

# %%
merge_ft.tail(9)
# Out:
#        year  rnd        type         team  tm_pts         opp_team  op_pts  \
# 15398  2018  R23  reg_season     St Kilda      94  North Melbourne     117
# 15399  2018   QF       final     Hawthorn      64         Richmond      95
# 15399  2018   QF       final     Richmond      95         Hawthorn      64
# 15400  2018   EF       final      Geelong      46        Melbourne      75
# 15400  2018   EF       final    Melbourne      75          Geelong      46
# 15401  2018   EF       final       Sydney      30       GWS Giants      79
# 15401  2018   EF       final   GWS Giants      79           Sydney      30
# 15402  2018   QF       final   West Coast      86      Collingwood      70
# 15402  2018   QF       final  Collingwood      70       West Coast      86
#
#                venue  tm  op  hvar  lr  tm_var outcome
# 15398      Docklands  SK  NM   -23   1     -23       L
# 15399         M.C.G.  HA  RI    31   0     -31       L
# 15399         M.C.G.  RI  HA    31   1      31       W
# 15400         M.C.G.  GE  ME    29   0     -29       L
# 15400         M.C.G.  ME  GE    29   1      29       W
# 15401         S.C.G.  SY  GW    49   0     -49       L
# 15401         S.C.G.  GW  SY    49   1      49       W
# 15402  Perth Stadium  WC  CO    16   1      16       W
# 15402  Perth Stadium  CO  WC    16   0     -16       L

# %% [markdown]
# ### Add the state column back in, using locations function.

# %%
merge_ft["state"] = merge_ft["venue"].apply(locations)
merge_ft["state"].value_counts()
# Out:
# VIC     26068
# WA       1282
# SA       1146
# NSW      1024
# QLD       948
# TAS       182
# ACT        96
# NT         48
# INTL       10
# Name: state, dtype: int64

# %% [markdown]
# ### Export enhanced results v2 with long format two rows per match

# %%
merge_ft.to_csv('enh_2_aflresults_long.csv')

# %% [markdown]
# ## Research for Week 2 of finals 2018 using Pandas filtering:
# ### * Hawthorn v Melbourne
# ### * Collingwood v GWS Giants

# %% [markdown]
# ### Recent contests Hawthorn v Melbourne

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'ME') & (merge_ft.op == 'HA')].tail(6)
# Out:
#        year  rnd        type       team  tm_pts  opp_team  op_pts   venue  tm  \
# 14539  2014  R20  reg_season  Melbourne      65  Hawthorn     115  M.C.G.  ME
# 14637  2015   R7  reg_season  Melbourne      50  Hawthorn     155  M.C.G.  ME
# 14878  2016  R11  reg_season  Melbourne      64  Hawthorn      82  M.C.G.  ME
# 14951  2016  R20  reg_season  Melbourne     110  Hawthorn      81  M.C.G.  ME
# 15055  2017   R7  reg_season  Melbourne      91  Hawthorn      94  M.C.G.  ME
# 15235  2018   R4  reg_season  Melbourne      48  Hawthorn     115  M.C.G.  ME
#
#        op  hvar  lr  tm_var outcome state
# 14539  HA    50   0     -50       L   VIC
# 14637  HA   105   0    -105       L   VIC
# 14878  HA    18   0     -18       L   VIC
# 14951  HA    29   1      29       W   VIC
# 15055  HA    -3   1      -3       L   VIC
# 15235  HA    67   0     -67       L   VIC

# %% [markdown]
# ### Hawks recent form

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'HA')].tail(10)
# Out:
#        year  rnd        type      team  tm_pts          opp_team  op_pts  \
# 15323  2018  R15  reg_season  Hawthorn      84        GWS Giants      95
# 15331  2018  R16  reg_season  Hawthorn     122  Western Bulldogs      59
# 15338  2018  R17  reg_season  Hawthorn      65          Brisbane      98
# 15351  2018  R18  reg_season  Hawthorn     124           Carlton      52
# 15362  2018  R19  reg_season  Hawthorn     112         Fremantle      53
# 15364  2018  R20  reg_season  Hawthorn     107          Essendon     103
# 15373  2018  R21  reg_season  Hawthorn      71           Geelong      60
# 15385  2018  R22  reg_season  Hawthorn      80          St Kilda      76
# 15395  2018  R23  reg_season  Hawthorn      83            Sydney      74
# 15399  2018   QF       final  Hawthorn      64          Richmond      95
#
#                    venue  tm  op  hvar  lr  tm_var outcome state
# 15323  Sydney Showground  HA  GW    11   0     -11       L   NSW
# 15331          Docklands  HA  WB   -63   0      63       W   VIC
# 15338          York Park  HA  BR   -33   1     -33       L   TAS
# 15351          Docklands  HA  CA   -72   0      72       W   VIC
# 15362      Perth Stadium  HA  FR   -59   0      59       W    WA
# 15364             M.C.G.  HA  ES     4   1       4       W   VIC
# 15373             M.C.G.  HA  GE    11   1      11       W   VIC
# 15385          Docklands  HA  SK    -4   0       4       W   VIC
# 15395             S.C.G.  HA  SY    -9   0       9       W   NSW
# 15399             M.C.G.  HA  RI    31   0     -31       L   VIC

# %% [markdown]
# ### Recent contests Collingwood v GWS in Melbourne

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.op == 'GW')].tail(12)
# Out:
#        year  rnd        type         team  tm_pts    opp_team  op_pts  \
# 14107  2012  R18  reg_season  Collingwood     174  GWS Giants      54
# 14314  2013  R18  reg_season  Collingwood     106  GWS Giants      66
# 14557  2014  R22  reg_season  Collingwood      75  GWS Giants      67
# 14675  2015  R11  reg_season  Collingwood     119  GWS Giants      77
# 14915  2016  R16  reg_season  Collingwood     125  GWS Giants      93
# 15060  2017   R8  reg_season  Collingwood      99  GWS Giants     102
# 15213  2018   R2  reg_season  Collingwood      79  GWS Giants      95
#
#                    venue  tm  op  hvar  lr  tm_var outcome state
# 14107  Sydney Showground  CO  GW  -120   0     120       W   NSW
# 14314             M.C.G.  CO  GW    40   1      40       W   VIC
# 14557  Sydney Showground  CO  GW    -8   0       8       W   NSW
# 14675             M.C.G.  CO  GW    42   1      42       W   VIC
# 14915  Sydney Showground  CO  GW   -32   0      32       W   NSW
# 15060  Sydney Showground  CO  GW     3   0      -3       L   NSW
# 15213             M.C.G.  CO  GW   -16   1     -16       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.op == 'GW') & (merge_ft.venue == 'M.C.G.')].tail(6)
# Out:
#        year  rnd        type         team  tm_pts    opp_team  op_pts   venue  \
# 14314  2013  R18  reg_season  Collingwood     106  GWS Giants      66  M.C.G.
# 14675  2015  R11  reg_season  Collingwood     119  GWS Giants      77  M.C.G.
# 15213  2018   R2  reg_season  Collingwood      79  GWS Giants      95  M.C.G.
#
#        tm  op  hvar  lr  tm_var outcome state
# 14314  CO  GW    40   1      40       W   VIC
# 14675  CO  GW    42   1      42       W   VIC
# 15213  CO  GW   -16   1     -16       L   VIC

# %% [markdown]
# ### Collingwood at the MCG in 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.venue == 'M.C.G.')&(merge_ft.year == 2018) ]
# Out:
#        year  rnd        type         team  tm_pts         opp_team  op_pts  \
# 15205  2018   R1  reg_season  Collingwood      67         Hawthorn     101
# 15213  2018   R2  reg_season  Collingwood      79       GWS Giants      95
# 15219  2018   R3  reg_season  Collingwood     100          Carlton      76
# 15245  2018   R5  reg_season  Collingwood     101         Essendon      52
# 15253  2018   R6  reg_season  Collingwood      70         Richmond     113
# 15272  2018   R8  reg_season  Collingwood      45          Geelong      66
# 15297  2018  R11  reg_season  Collingwood     138        Fremantle      77
# 15305  2018  R12  reg_season  Collingwood     133        Melbourne      91
# 15317  2018  R14  reg_season  Collingwood      79          Carlton      59
# 15334  2018  R16  reg_season  Collingwood      78         Essendon      62
# 15342  2018  R17  reg_season  Collingwood      67       West Coast     102
# 15346  2018  R18  reg_season  Collingwood     130  North Melbourne      64
# 15355  2018  R19  reg_season  Collingwood      77         Richmond     105
# 15382  2018  R22  reg_season  Collingwood     115    Port Adelaide      64
#
#         venue  tm  op  hvar  lr  tm_var outcome state
# 15205  M.C.G.  CO  HA    34   0     -34       L   VIC
# 15213  M.C.G.  CO  GW   -16   1     -16       L   VIC
# 15219  M.C.G.  CO  CA   -24   0      24       W   VIC
# 15245  M.C.G.  CO  ES    49   1      49       W   VIC
# 15253  M.C.G.  CO  RI   -43   1     -43       L   VIC
# 15272  M.C.G.  CO  GE   -21   1     -21       L   VIC
# 15297  M.C.G.  CO  FR    61   1      61       W   VIC
# 15305  M.C.G.  CO  ME   -42   0      42       W   VIC
# 15317  M.C.G.  CO  CA    20   1      20       W   VIC
# 15334  M.C.G.  CO  ES   -16   0      16       W   VIC
# 15342  M.C.G.  CO  WC   -35   1     -35       L   VIC
# 15346  M.C.G.  CO  NM    66   1      66       W   VIC
# 15355  M.C.G.  CO  RI    28   0     -28       L   VIC
# 15382  M.C.G.  CO  PA    51   1      51       W   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'CO') & (merge_ft.venue == 'M.C.G.')&(merge_ft.year == 2018)].median()
# Out:
# year      2018.0
# tm_pts      79.0
# op_pts      76.5
# hvar         2.0
# lr           1.0
# tm_var      18.0
# dtype: float64

# %% [markdown]
# ### GWS' performances in Victoria: 2017 and 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year >= 2017)&(merge_ft.state == 'VIC')]
# Out:
#        year  rnd        type        team  tm_pts          opp_team  op_pts  \
# 15048  2017   R7  reg_season  GWS Giants      85          St Kilda     108
# 15094  2017  R12  reg_season  GWS Giants      70           Carlton      71
# 15144  2017  R18  reg_season  GWS Giants      45          Richmond      64
# 15165  2017  R21  reg_season  GWS Giants     105  Western Bulldogs      57
# 15187  2017  R23  reg_season  GWS Giants      59           Geelong     103
# 15199  2017   PF       final  GWS Giants      67          Richmond     103
# 15213  2018   R2  reg_season  GWS Giants      95       Collingwood      79
# 15238  2018   R5  reg_season  GWS Giants      73          St Kilda      73
# 15255  2018   R7  reg_season  GWS Giants      32           Geelong      93
# 15369  2018  R20  reg_season  GWS Giants     151           Carlton      46
# 15397  2018  R23  reg_season  GWS Giants      57         Melbourne     102
#
#                venue  tm  op  hvar  lr  tm_var outcome state
# 15048      Docklands  GW  SK    23   0     -23       L   VIC
# 15094      Docklands  GW  CA     1   0      -1       L   VIC
# 15144         M.C.G.  GW  RI    19   0     -19       L   VIC
# 15165      Docklands  GW  WB   -48   0      48       W   VIC
# 15187  Kardinia Park  GW  GE    44   0     -44       L   VIC
# 15199         M.C.G.  GW  RI    36   0     -36       L   VIC
# 15213         M.C.G.  GW  CO   -16   0      16       W   VIC
# 15238      Docklands  GW  SK     0   0       0       D   VIC
# 15255  Kardinia Park  GW  GE    61   0     -61       L   VIC
# 15369      Docklands  GW  CA  -105   0     105       W   VIC
# 15397         M.C.G.  GW  ME    45   0     -45       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year >= 2017)&(merge_ft.state == 'VIC')].median()
# Out:
# year      2017.0
# tm_pts      70.0
# op_pts      79.0
# hvar        19.0
# lr           0.0
# tm_var     -19.0
# dtype: float64

# %% [markdown]
# ### GWS' outside NSW in 2018

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year > 2017)&(merge_ft.state != 'NSW')]
# Out:
#        year  rnd        type        team  tm_pts          opp_team  op_pts  \
# 15207  2018   R1  reg_season  GWS Giants     133  Western Bulldogs      51
# 15213  2018   R2  reg_season  GWS Giants      95       Collingwood      79
# 15229  2018   R4  reg_season  GWS Giants      82         Fremantle      51
# 15238  2018   R5  reg_season  GWS Giants      73          St Kilda      73
# 15255  2018   R7  reg_season  GWS Giants      32           Geelong      93
# 15275  2018   R9  reg_season  GWS Giants      69   North Melbourne     112
# 15298  2018  R11  reg_season  GWS Giants      97          Adelaide      81
# 15315  2018  R14  reg_season  GWS Giants     109          Brisbane      82
# 15335  2018  R16  reg_season  GWS Giants      75        West Coast      86
# 15353  2018  R18  reg_season  GWS Giants      80     Port Adelaide      58
# 15369  2018  R20  reg_season  GWS Giants     151           Carlton      46
# 15376  2018  R21  reg_season  GWS Giants     106          Adelaide      92
# 15397  2018  R23  reg_season  GWS Giants      57         Melbourne     102
#
#                 venue  tm  op  hvar  lr  tm_var outcome state
# 15207     Manuka Oval  GW  WB    82   1      82       W   ACT
# 15213          M.C.G.  GW  CO   -16   0      16       W   VIC
# 15229     Manuka Oval  GW  FR    31   1      31       W   ACT
# 15238       Docklands  GW  SK     0   0       0       D   VIC
# 15255   Kardinia Park  GW  GE    61   0     -61       L   VIC
# 15275  Bellerive Oval  GW  NM    43   0     -43       L   TAS
# 15298   Adelaide Oval  GW  AD   -16   0      16       W    SA
# 15315           Gabba  GW  BR   -27   0      27       W   QLD
# 15335   Perth Stadium  GW  WC    11   0     -11       L    WA
# 15353   Adelaide Oval  GW  PA   -22   0      22       W    SA
# 15369       Docklands  GW  CA  -105   0     105       W   VIC
# 15376     Manuka Oval  GW  AD    14   1      14       W   ACT
# 15397          M.C.G.  GW  ME    45   0     -45       L   VIC

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'GW') & (merge_ft.year > 2017)&(merge_ft.state != 'NSW')].median()
# Out:
# year      2018.0
# tm_pts      82.0
# op_pts      81.0
# hvar        11.0
# lr           0.0
# tm_var      16.0
# dtype: float64

# %% [markdown]
# ### Review Hawks finals performances since 2016

# %%
merge_ft.iloc[:,:][(merge_ft.tm == 'HA') & (merge_ft.year >= 2016)&(merge_ft.type == 'final')]
# Out:
#        year rnd   type      team  tm_pts          opp_team  op_pts   venue  \
# 14986  2016  QF  final  Hawthorn      83           Geelong      85  M.C.G.
# 14989  2016  SF  final  Hawthorn      84  Western Bulldogs     107  M.C.G.
# 15399  2018  QF  final  Hawthorn      64          Richmond      95  M.C.G.
#
#        tm  op  hvar  lr  tm_var outcome state
# 14986  HA  GE     2   0      -2       L   VIC
# 14989  HA  WB    23   0     -23       L   VIC
# 15399  HA  RI    31   0     -31       L   VIC
